# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
import joblib
import datasets

# %% [markdown]
# # Train

# %%
import re

def remove_image_string(input_string):
    pattern = r"!\[(.*?)\]\(.*?\)\{width=\".*?\" height=\".*?\"\}|!\[.*?\]\(.*?\)|\[.*?\]\{.*?\}"
    result = re.sub(pattern, "", input_string)
    return result

def remove_noise_character(input_string):
    pattern = r"[>*|image|data|media|png]"
    
    return re.sub(pattern, "", input_string)

def one_text_pre_process(text):
    precessed_text_split_lines = []
    
    for line in text.splitlines():
        remove_image_line = remove_image_string(line)

        if remove_image_line.strip() in ["", ">"]:
            continue

        remove_image_line = remove_noise_character(remove_image_line)
        precessed_text_split_lines.append(remove_image_line)
        
    return "\n".join(precessed_text_split_lines)

def pre_process(text_list):
    precessed_text_list = [one_text_pre_process(text) for text in text_list]
    return precessed_text_list

def dataset_map_pre_process(row):
    row["text"] = one_text_pre_process(row["text"])
    return row

# %%
import jieba

def chinese_tokenizer(text):
    tokens = jieba.cut(text)
    return list(tokens)

vocabulary = {
    "考试",
    "选择题",
    "判断题",
    "填空题",
    "试卷",
    "单元",
    "单元测试",
    "答案",
    "分数",
    "简答题",
    "试题",
    "高考",
    "考试真题",
    "真题"
}


def train(dataset):
#     不建议手动特征
#     vectorizer = CountVectorizer(vocabulary=vocabulary, tokenizer=chinese_tokenizer, ngram_range=(1, 5))
    vectorizer = CountVectorizer(tokenizer=chinese_tokenizer, ngram_range=(1, 10))
    classifier = LogisticRegression(max_iter=1500, verbose=1)
    model = make_pipeline(vectorizer, classifier)
    
    model.fit(dataset["text"], dataset["label"])
    return model

# %%
datadict = datasets.load_from_disk("./dataset")

# %%
train_dataset = datadict["train"]

# %%
train_dataset = train_dataset.map(dataset_map_pre_process)
# Out:
# Loading cached processed dataset at /home/ran/WorkSpace/my_Exam-Question-Bank-Dataset-zh_mnbvc/notebook/dataset/train/cache-fdb59d6d907c2395.arrow

# %%
model = train(train_dataset)
# Out:
# /home/ran/.local/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.300 seconds.
# Prefix dict has been built successfully.
# [Parallel(n_jobs=15)]: Using backend LokyBackend with 15 concurrent workers.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =     63301645     M =           10
#
# At X0         0 variables are exactly at the bounds
#  This problem is unconstrained.
# At iterate    0    f=  1.92626D+03    |proj g|=  3.63434D+05
#
# At iterate   50    f=  2.12263D+02    |proj g|=  1.73208D+04
#
# At iterate  100    f=  9.04706D+01    |proj g|=  2.90586D+03
#
# At iterate  150    f=  4.50236D+01    |proj g|=  8.43264D+01
#
# At iterate  200    f=  3.28981D+01    |proj g|=  9.14091D+00
#
# At iterate  250    f=  2.79421D+01    |proj g|=  4.21906D+01
#
# At iterate  300    f=  2.52349D+01    |proj g|=  6.07052D+00
#
# At iterate  350    f=  2.40528D+01    |proj g|=  9.27223D+01
#
# At iterate  400    f=  2.37315D+01    |proj g|=  4.99852D+01
#
# At iterate  450    f=  2.32382D+01    |proj g|=  2.81430D+01
#
# At iterate  500    f=  2.30191D+01    |proj g|=  5.25895D+00
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate  550    f=  2.19636D+01    |proj g|=  2.12715D+01
#
# At iterate  600    f=  2.13172D+01    |proj g|=  5.21387D+00
#
# At iterate  650    f=  2.09607D+01    |proj g|=  3.10798D+00
#
# At iterate  700    f=  2.07168D+01    |proj g|=  1.22201D+01
#
# At iterate  750    f=  2.05378D+01    |proj g|=  4.68612D+00
#
# At iterate  800    f=  2.04890D+01    |proj g|=  5.96808D+00
#
# At iterate  850    f=  2.04561D+01    |proj g|=  2.75782D-01
#
# At iterate  900    f=  2.04441D+01    |proj g|=  2.57272D-01
#
# At iterate  950    f=  2.04385D+01    |proj g|=  9.24879D-01
#
# At iterate 1000    f=  2.04332D+01    |proj g|=  7.97755D-01
#
# At iterate 1050    f=  2.04321D+01    |proj g|=  1.46332D-01
#
# At iterate 1100    f=  2.04307D+01    |proj g|=  5.60908D-01
#
# At iterate 1150    f=  2.04298D+01    |proj g|=  3.29849D-01
#
# At iterate 1200    f=  2.04293D+01    |proj g|=  3.31572D-01
#
# At iterate 1250    f=  2.04291D+01    |proj g|=  6.40701D-01
#
# At iterate 1300    f=  2.04290D+01    |proj g|=  2.19112D+00
#
# At iterate 1350    f=  2.04288D+01    |proj g|=  1.43828D-01
#
# At iterate 1400    f=  2.04287D+01    |proj g|=  7.81361D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# *****   1437   2616      2     0     0   1.434D-01   2.043D+01
#   F =   20.428623628188980
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Parallel(n_jobs=15)]: Done   1 out of   1 | elapsed: 168.6min finished

# %%
joblib.dump(model, 'TextClassifier-new-63m.pkl')
# Out:
# ['TextClassifier-new-63m.pkl']

# %% [markdown]
# # 模型数据

# %%
print("模型方程: y = ", model.named_steps['logisticregression'].coef_, " * x + ", model.named_steps['logisticregression'].intercept_)

print("参数量: ", model.named_steps['logisticregression'].coef_.size + 1)
# Out:
# 模型方程: y =  [[ 6.42874349e-02 -6.07271510e-04  4.35482550e-07 ...  1.78620692e-08
#    1.78620692e-08  1.78620692e-08]]  * x +  [-2.08611946]
# 参数量:  63301645

# %%
count_vectorizer = model.steps[0][1]

# %%
count_vectorizer.vocabulary_
# Out:
# {'北师大': 29165570,
#  '版': 44338147,
#  '小学': 34922410,
#  '三年级': 20997501,
#  '下册': 21346892,
#  '数学': 39892831,
#  '第六': 48709930,
#  '单元': 29386602,
#  '《': 19861441,
#  '认识': 51865032,
#  '分数': 28058549,
#  '》': 19894146,
#  '单元测试': 29388936,
#  '3': 9261980,
#  '（': 55829287,
#  '附': 54713684,
#  '答案': 48917215,
#  '）': 56486272,
#  '\n': 0,
#  '一': 20342601,
#  '、': 18039995,
#  '用': 44773335,
#  '表示': 51021178,
#  '下面': 21394465,
#  '每个': 42972104,
#  '图里': 32105772,
#  '的': 45209542,
#  '阴影': 54690534,
#  '部分': 53967706,
#  '。': 19007634,
#  '每空': 43028459,
#  '2': 8403637,
#  '分': 27846262,
#  '，': 57369775,
#  '共': 26962411,
#  '12': 8108522,
#  '二': 24110146,
#  '判断题': 28554433,
#  '对': 34553114,
#  '在': 32187508,
#  '括号': 38893746,
#  '里': 54130366,
#  '打': 38435451,
#  '"': 4582718,
#  '√': 17123744,
#  '错': 54373799,
#  '×': 16707845,
#  '10': 7962922,
#  '1': 7448140,
#  ' ': 1953046,
#  '是': 40813791,
#  '同': 30815750,
#  '分母': 28160591,
#  '相加': 47732440,
#  '减': 27552097,
#  '不变': 21562281,
#  '分子': 28024464,
#  '＋': 57286434,
#  '=': 10736687,
#  '4': 9667429,
#  '如': 33649517,
#  '左图': 35516040,
#  '长方形': 54474972,
#  '与': 21821875,
#  '正方形': 42803709,
#  '一样': 20720437,
#  '大': 33279852,
#  '5': 9963717,
#  '有': 41559433,
#  '个球': 22490792,
#  '拿出': 38909983,
#  '应该': 36243921,
#  '拿': 38905940,
#  '个': 22366304,
#  '三': 20931760,
#  '填空题': 33007678,
#  '第': 48618388,
#  '题': 55257364,
#  '16': 8287375,
#  '24': 9117378,
#  '52': 10133274,
#  '个数': 22474708,
#  '点': 44070080,
#  '全部': 26772100,
#  '占': 29436806,
#  '来源': 42180123,
#  '：': 62125614,
#  'www': 15539621,
#  '.': 6683145,
#  'bcjy123': 13004765,
#  'co': 13415868,
#  '/': 7170932,
#  'ku': 14260777,
#  '○': 17824062,
#  '填上': 32998456,
#  '﹥': 55800054,
#  '﹤': 55798962,
#  '或': 38066072,
#  '直接': 47538045,
#  '写出': 27430623,
#  '得数': 37137321,
#  '－': 61460633,
#  '四': 31725036,
#  '解决问题': 51575796,
#  '8': 10440141,
#  '其余': 27237219,
#  '每题': 43034211,
#  '9': 10564522,
#  '26': 9165491,
#  '一块': 20598336,
#  '月饼': 41559333,
#  '小明': 34961675,
#  '吃': 30677518,
#  '了': 23788486,
#  '小': 34878462,
#  '李': 42063066,
#  '他们': 24916676,
#  '一共': 20550270,
#  '这个': 53321455,
#  '饼': 55389353,
#  '几分': 27618521,
#  '之': 23472007,
#  '几': 27589749,
#  '？': 63219244,
#  '还': 53209617,
#  '剩下': 28836902,
#  '画出': 45111345,
#  '如下': 33662260,
#  '图形': 32044777,
#  '两种': 22296725,
#  '不同': 21577354,
#  '法': 43552554,
#  '红': 49275506,
#  '金鱼': 54290471,
#  '条': 42106399,
#  '黄金': 55580211,
#  '鱼': 55553952,
#  '黑': 55582158,
#  '请': 52310048,
#  '你': 25694120,
#  '提出': 39273737,
#  '有关': 41733831,
#  '问题': 54526387,
#  '并': 36095905,
#  '解决': 51553135,
#  '卷': 29595587,
#  '0': 7202712,
#  '北师大 版': 29165633,
#  '版 小学': 44338784,
#  '小学 三年级': 34922856,
#  '三年级 下册': 20997691,
#  '下册 数学': 21346991,
#  '数学 第六': 39909292,
#  '第六 单元': 48709980,
#  '单元 《': 29386996,
#  '《 认识': 19890249,
#  '认识 分数': 51868602,
#  '分数 》': 28059527,
#  '》 单元测试': 19906131,
#  '单元测试 3': 29389000,
#  '3 （': 9431007,
#  '（ 附': 56440070,
#  '附 答案': 54713890,
#  '答案 ）': 48959012,
#  '） \n': 56486273,
#  '\n 一': 1093080,
#  '一 、': 20348298,
#  '、 用': 18766495,
#  '用 分数': 44794909,
#  '分数 表示': 28066989,
#  '表示 下面': 51026393,
#  '下面 每个': 21400915,
#  '每个 图里': 42976123,
#  '图里 的': 32105808,
#  '的 阴影': 47302441,
#  '阴影 部分': 54691306,
#  '部分 。': 53969207,
#  '。 （': 19845780,
#  '（ 每空': 56406694,
#  '每空 2': 43028970,
#  '2 分': 8721725,
#  '分 ，': 27953677,
#  '， 共': 58697541,
#  '共 12': 26964777,
#  '12 分': 8127643,
#  '分 ）': 27886211,
#  '\n 二': 1153304,
#  '二 、': 24113763,
#  '、 判断题': 18356814,
#  '判断题 。': 28554535,
#  '（ 对': 56378399,
#  '对 的': 34633318,
#  '的 在': 45954575,
#  '在 括号': 32397040,
#  '括号 里': 38895091,
#  '里 打': 54137389,
#  '打 "': 38435452,
#  '" √': 4695185,
#  '√ "': 17125525,
#  '" ，': 5370572,
#  '， 错': 61281759,
#  '错 的': 54375042,
#  '的 打': 46353861,
#  '" ×': 4693725,
#  '× "': 16712464,
#  '" 。': 4709105,
#  '。 ）': 19855347,
#  '） （': 57153226,
#  '共 10': 26962852,
#  '10 分': 7994432,
#  '\n 1': 303500,
#  '1 、': 7653736,
#  '、  ': 18043624,
#  '  是': 4300685,
#  '是 表示': 41180681,
#  '表示 阴影': 51051145,
#  '部分 的': 53979855,
#  '的 分数': 45705432,
#  '分数 。': 28059302,
#  '。  ': 19279698,
#  '  （': 4449389,
#  '（  ': 55829390,
#  '  ）': 4494447,
#  '\n 2': 396242,
#  '2 、': 8690922,
#  '、 同': 18409990,
#  '同 分母': 30820286,
#  '分母 分数': 28161902,
#  '分数 相加': 28066766,
#  '相加 减': 47732691,
#  '减 ，': 27557009,
#  '， 分母': 58818654,
#  '分母 不变': 28161038,
#  '不变 ，': 21566380,
#  '， 分子': 58815136,
#  '分子 相加': 28029493,
#  '减 。': 27552826,
#  '\n 3': 461766,
#  '3 、': 9366251,
#  '、 ＋': 19002066,
#  '＋  ': 57286864,
#  '  =': 2763177,
#  '=  ': 10753024,
#  '\n 4': 495510,
#  '4 、': 9742629,
#  '  如': 4216675,
#  '如 左图': 33655170,
#  '左图 长方形': 35516240,
#  '长方形 的': 54477874,
#  '的 与': 45361165,
#  '与 正方形': 21955744,
#  '正方形 的': 42810719,
#  '的 一样': 45322882,
#  '一样 大': 20722983,
#  '大 。': 33283299,
#  '\n 5': 519745,
#  '5 、': 10010975,
#  '、 有': 18682558,
#  '有 12': 41572538,
#  '12 个球': 8126532,
#  '个球 ，': 22491648,
#  '， 拿出': 60026857,
#  '拿出 ，': 38912493,
#  '， 应该': 59693897,
#  '应该 拿': 36247406,
#  '拿 3': 38906027,
#  '3 个': 9377178,
#  '个 。': 22377933,
#  '\n 三': 1115321,
#  '三 、': 20934539,
#  '、 填空题': 18452741,
#  '填空题 。': 33009000,
#  '（ 第': 56419228,
#  '第 1': 48619379,
#  '1 题': 7729965,
#  '题 12': 55262169,
#  '， 第': 60735562,
#  '第 2': 48623635,
#  '2 题': 8762256,
#  '题 16': 55262296,
#  '16 分': 8299130,
#  '第 3': 48627262,
#  '3 题': 9427577,
#  '题 24': 55262536,
#  '24 分': 9125406,
#  '共 52': 26976653,
#  '52 分': 10134795,
#  '、 \n': 18039996,
#  '\n （': 1781628,
#  '（ 1': 55877967,
#  '1 ）': 7741972,
#  '）  ': 56586495,
#  '  的': 4350713,
#  '的 个数': 45387396,
#  '个数 点': 22483380,
#  '点 全部': 44119865,
#  '全部 的': 26776628,
#  '的 。': 45284211,
#  '。 \n': 19007635,
#  '（ 2': 55981227,
#  '2 ）': 8773696,
#  '   ': 1976679,
#  '个数 占': 22479689,
#  '占 全部': 29439165,
#  '。 来源': 19687876,
#  '来源 ：': 42182269,
#  '： www': 62313436,
#  'www .': 15539631,
#  '. bcjy123': 6972058,
#  'bcjy123 .': 13004766,
#  '. co': 6974588,
#  'co /': 13424833,
#  '/ ku': 7190456,
#  'ku /': 14260804,
#  '/ \n': 7170933,
#  '（ 3': 56077403,
#  '3 ）': 9432810,
#  '） 与': 56779285,
#  '与  ': 21822117,
#  '、 在': 18434741,
#  '在 ○': 32228122,
#  '○ 里': 17830010,
#  '里 填上': 54135699,
#  '填上 "': 32998466,
#  '" ﹥': 5367700,
#  '﹥ "': 55800350,
#  '" "': 4628404,
#  '" ﹤': 5367649,
#  '﹤ "': 55799405,
#  '" 或': 5062997,
#  '或 "': 38069245,
#  '" =': 4660497,
#  '= "': 10778449,
#  '1 \n': 7448141,
#  '、 直接': 18781967,
#  '直接 写出': 47539690,
#  '写出 得数': 27436400,
#  '得数 。': 37137526,
#  '\n ＋': 1914306,
#  '  －': 4547912,
#  '－  ': 61461522,
#  '  ＋': 4530250,
#  '= \n': 10736688,
#  '\n －': 1940249,
#  '  1': 2557957,
#  '1 －': 7904842,
#  '\n 四': 1326436,
#  '四 、': 31726676,
#  '、 解决问题': 18895650,
#  '解决问题 。': 51576357,
#  '题 8': 55263080,
#  '8 分': 10477134,
#  '， 其余': 58744084,
#  '其余 每题': 27238567,
#  '每题 9': 43035818,
#  '9 分': 10591505,
#  '共 26': 26970768,
#  '26 分': 9169140,
#  '、 一块': 18181529,
#  '一块 月饼': 20599702,
#  '月饼 ，': 41559414,
#  '， 小明': 59572793,
#  '小明 吃': 34963439,
#  '吃 了': 30679264,
#  '了 ，': 24007364,
#  '， 小': 59568168,
#  '小 李': 34886144,
#  '李 吃': 42063418,
#  '了 。': 23815240,
#  '） 他们': 56802339,
#  '他们 一共': 24917092,
#  '一共 吃': 20551440,
#  '了 这个': 23993428,
#  '这个 饼': 53355321,
#  '饼 的': 55389464,
#  '的 几分': 45690247,
#  '几分 之': 27618548,
#  '之 几': 23478215,
#  '几 ？': 27591739,
#  '？ \n': 63219245,
#  '） 还': 57132743,
#  '还 剩下': 53221488,
#  '剩下 几分': 28838477,
#  '用 阴影': 44836924,
#  '阴影 画出': 54691175,
#  '画出 如下': 45114378,
#  '如下 图形': 33665469,
#  '图形 的': 32055038,
#  '的 ，': 47398350,
#  '， 画出': 60625549,
#  '画出 两种': 45112201,
#  '两种 不同': 22296806,
#  '不同 分': 21579142,
#  '分 法': 27882054,
#  '法 。': 43556579,
#  '、 红': 18830642,
#  '红 金鱼': 49277564,
#  '金鱼 3': 54290481,
#  '3 条': 9416333,
#  '条 ，': 42111619,
#  '， 黄金': 61348687,
#  '黄金 鱼': 55580717,
#  '鱼 4': 55554013,
#  '4 条': 9782759,
#  '其余 的': 27238688,
#  '的 是': 46515185,
#  '是 黑': 41217979,
#  '黑 金鱼': 55584100,
#  '金鱼 。': 54290504,
#  '\n 请': 1747369,
#  '请 你': 52311405,
#  '你 提出': 25717532,
#  '提出 有关': 39280465,
#  '有关 分数': 41736312,
#  '分数 的': 28064651,
#  '的 数学': 46419573,
#  '数学 问题': 39911396,
#  '问题 并': 54563367,
#  '并 解决': 36126297,
#  '解决 。': 51554322,
#  '  ？': 4576059,
#  '\n 第六': 1636714,
#  '第六 单元测试': 48710091,
#  '单元测试 卷': 29389067,
#  '卷 的': 29600185,
#  '的 部分': 47227178,
#  '部分 答案': 53983929,
#  '答案 ：': 48961660,
#  '： \n': 62125615,
#  '、 ×': 18165538,
#  '×  ': 16709814,
#  '  √': 3999566,
#  '√  ': 17124353,
#  '  ×': 3985285,
#  '√ \n': 17123745,
#  '、 1': 18069375,
#  '、 （': 18996644,
#  '、 ﹥': 18996562,
#  '﹥  ': 55800102,
#  '  ﹥': 4448975,
#  '  ﹤': 4448634,
#  '﹤  ': 55799069,
#  '﹥ \n': 55800055,
#  '1  ': 7456213,
#  '  0': 2541913,
#  '0 \n': 7202713,
#  '北师大 版 小学': 29165931,
#  '版 小学 三年级': 44338813,
#  '小学 三年级 下册': 34922900,
#  '三年级 下册 数学': 20997692,
#  '下册 数学 第六': 21347268,
#  '数学 第六 单元': 39909293,
#  '第六 单元 《': 48709981,
#  '单元 《 认识': 29387385,
#  '《 认识 分数': 19890270,
#  '认识 分数 》': 51868633,
#  '分数 》 单元测试': 28059528,
#  '》 单元测试 3': 19906170,
#  '单元测试 3 （': 29389001,
#  '3 （ 附': 9432613,
#  '（ 附 答案': 56440079,
#  '附 答案 ）': 54714109,
#  '答案 ） \n': 48959013,
#  '） \n 一': 56552110,
#  '\n 一 、': 1093382,
#  '一 、 用': 20357619,
#  '、 用 分数': 18767063,
#  '用 分数 表示': 44794972,
#  '分数 表示 下面': 28067033,
#  '表示 下面 每个': 51026441,
#  '下面 每个 图里': 21400931,
#  '每个 图里 的': 42976124,
#  '图里 的 阴影': 32105817,
#  '的 阴影 部分': 47302498,
#  '阴影 部分 。': 54691459,
#  '部分 。 （': 53969679,
#  '。 （ 每空': 19853268,
#  '（ 每空 2': 56406885,
#  '每空 2 分': 43028971,
#  '2 分 ，': 8728478,
#  '分 ， 共': 27955351,
#  '， 共 12': 58698231,
#  '共 12 分': 26964861,
#  '12 分 ）': 8129746,
#  '分 ） \n': 27886212,
#  '） \n 二': 56555427,
#  '\n 二 、': 1153625,
#  '二 、 判断题': 24117607,
#  '、 判断题 。': 18356880,
#  '判断题 。 （': 28554633,
#  '。 （ 对': 19852336,
#  '（ 对 的': 56378432,
#  '对 的 在': 34634066,
#  '的 在 括号': 45954864,
#  '在 括号 里': 32397193,
#  '括号 里 打': 38895724,
#  '里 打 "': 54137390,
#  '打 " √': 38435889,
#  '" √ "': 4695219,
#  '√ " ，': 17125961,
#  '" ， 错': 5443393,
#  '， 错 的': 61281775,
#  '错 的 打': 54375129,
#  '的 打 "': 46353862,
#  '打 " ×': 38435529,
#  '" × "': 4693726,
#  '× " 。': 16712694,
#  '" 。 ）': 4741201,
#  '。 ） （': 19856559,
#  '） （ 每空': 57172557,
#  '， 共 10': 58697676,
#  '共 10 分': 26963029,
#  '10 分 ）': 7996556,
#  '） \n 1': 56501718,
#  '\n 1 、': 313758,
#  '1 、  ': 7653975,
#  '、   是': 18052775,
#  '  是 表示': 4302723,
#  '是 表示 阴影': 41180757,
#  '表示 阴影 部分': 51051146,
#  '阴影 部分 的': 54692246,
#  '部分 的 分数': 53980327,
#  '的 分数 。': 45705502,
#  '分数 。  ': 28059456,
#  '。   （': 19289185,
#  '  （  ': 4449419,
#  '（   ）': 55834826,
#  '  ） \n': 4494448,
#  '） \n 2': 56513331,
#  '\n 2 、': 406603,
#  '2 、 同': 8697817,
#  '、 同 分母': 18410147,
#  '同 分母 分数': 30820346,
#  '分母 分数 相加': 28162066,
#  '分数 相加 减': 28066775,
#  '相加 减 ，': 47732757,
#  '减 ， 分母': 27557133,
#  '， 分母 不变': 58818767,
#  '分母 不变 ，': 28161047,
#  '不变 ， 分子': 21567040,
#  '， 分子 相加': 58815690,
#  '分子 相加 减': 28029502,
#  '相加 减 。': 47732700,
#  '减 。  ': 27552854,
#  '） \n 3': 56519165,
#  '\n 3 、': 470109,
#  '3 、 ＋': 9375314,
#  '、 ＋  ': 19002067,
#  '＋   =': 57287175,
#  '  =  ': 2764500,
#  '=   （': 10777200,
#  '） \n 4': 56521860,
#  '\n 4 、': 502259,
#  '4 、  ': 9742770,
#  '、   如': 18050168,
#  '  如 左图': 4216853,
#  '如 左图 长方形': 33655171,
#  '左图 长方形 的': 35516241,
#  '长方形 的 与': 54477948,
#  '的 与 正方形': 45361421,
#  '与 正方形 的': 21955871,
#  '正方形 的 一样': 42810798,
#  '的 一样 大': 45322959,
#  '一样 大 。': 20723125,
#  '大 。  ': 33283784,
#  '） \n 5': 56523580,
#  '\n 5 、': 525242,
#  '5 、 有': 10014923,
#  '、 有 12': 18682640,
#  '有 12 个球': 41572801,
#  '12 个球 ，': 8126549,
#  '个球 ， 拿出': 22492097,
#  '， 拿出 ，': 60027573,
#  '拿出 ， 应该': 38912494,
#  '， 应该 拿': 59694255,
#  '应该 拿 3': 36247407,
#  '拿 3 个': 38906028,
#  '3 个 。': 9377982,
#  '个 。  ': 22379245,
#  '） \n 三': 56553687,
#  '\n 三 、': 1115590,
#  '三 、 填空题': 20939312,
#  '、 填空题 。': 18453631,
#  '填空题 。 （': 33009235,
#  '。 （ 第': 19853886,
#  '（ 第 1': 56419318,
#  '第 1 题': 48620946,
#  '1 题 12': 7730005,
#  '题 12 分': 55262170,
#  '12 分 ，': 8136205,
#  '分 ， 第': 27963145,
#  '， 第 2': 60736416,
#  '第 2 题': 48624983,
#  '2 题 16': 8762314,
#  '题 16 分': 55262297,
#  '16 分 ，': 8300474,
#  '， 第 3': 60737170,
#  '第 3 题': 48628573,
#  '3 题 24': 9427612,
#  '题 24 分': 55262537,
#  '24 分 ，': 9126214,
#  '， 共 52': 58703387,
#  '共 52 分': 26976654,
#  '52 分 ）': 10134811,
#  '1 、 \n': 7653737,
#  '、 \n （': 18043407,
#  '\n （ 1': 1782666,
#  '（ 1 ）': 55889337,
#  '1 ）  ': 7744313,
#  '）   的': 56600064,
#  '  的 个数': 4351051,
#  '的 个数 点': 45391495,
#  '个数 点 全部': 22483381,
#  '点 全部 的': 44119866,
#  '全部 的 。': 26776727,
#  '的 。 \n': 45284212,
#  '。 \n （': 19259340,
#  '\n （ 2': 1805154,
#  '（ 2 ）': 55989431,
#  '2 ）  ': 8775986,
#  '）    ': 56586746,
#  '    的': 2376993,
#  '的 个数 占': 45389684,
#  '个数 占 全部': 22479690,
#  '占 全部 的': 29439237,
#  '的 。 来源': 45295362,
#  '。 来源 ：': 19687877,
#  '来源 ： www': 42182294,
#  '： www .': 62313445,
#  'www . bcjy123': 15539632,
#  '. bcjy123 .': 6972059,
#  'bcjy123 . co': 13004767,
#  '. co /': 6975150,
#  'co / ku': 13425222,
#  '/ ku /': 7190457,
#  'ku / \n': 14260805,
#  '/ \n （': 7174453,
#  '\n （ 3': 1842629,
#  '（ 3 ）': 56084726,
#  '3 ） 与': 9443173,
#  '） 与  ': 56779294,
#  '与    ': 21822118,
#  '。 \n 2': 19061349,
#  '2 、 在': 8698060,
#  '、 在 ○': 18435082,
#  '在 ○ 里': 32228177,
#  '○ 里 填上': 17830056,
#  '里 填上 "': 54135708,
#  '填上 " ﹥': 32998587,
#  '" ﹥ "': 5367701,
#  '﹥ " "': 55800351,
#  '" " ﹤': 4647490,
#  '" ﹤ "': 5367650,
#  '﹤ " 或': 55799430,
#  '" 或 "': 5063006,
#  '或 " =': 38069400,
#  '" = "': 4660517,
#  '= " 。': 10778870,
#  '" 。 \n': 4709106,
#  '。 \n 1': 19046137,
#  '\n 1 \n': 303501,
#  '1 \n 3': 7450674,
#  '3 、 直接': 9374019,
#  '、 直接 写出': 18782064,
#  '直接 写出 得数': 47540222,
#  '写出 得数 。': 27436435,
#  '得数 。 \n': 37137527,
#  '。 \n ＋': 19279207,
#  '\n ＋  ': 1914307,
#  '=   －': 10778210,
#  '  －  ': 4547966,
#  '－   =': 61461813,
#  '=   ＋': 10777689,
#  '  ＋  ': 4530297,
#  '  = \n': 2763178,
#  '= \n ＋': 10752882,
#  '= \n －': 10752933,
#  '\n －  ': 1940250,
#  '=   1': 10757637,
#  '  1 －': 2568526,
#  '1 －  ': 7904907,
#  '= \n 四': 10748796,
#  '\n 四 、': 1326549,
#  '四 、 解决问题': 31733470,
#  '、 解决问题 。': 18895803,
#  '解决问题 。 （': 51577739,
#  '1 题 8': 7730116,
#  '题 8 分': 55263089,
#  '8 分 ，': 10481790,
#  '分 ， 其余': 27959452,
#  '， 其余 每题': 58744853,
#  '其余 每题 9': 27238629,
#  '每题 9 分': 43035819,
#  '9 分 ，': 10593366,
#  '， 共 26': 58700920,
#  '共 26 分': 26970769,
#  '26 分 ）': 9169239,
#  '1 、 一块': 7658414,
#  '、 一块 月饼': 18181585,
#  '一块 月饼 ，': 20599711,
#  '月饼 ， 小明': 41559415,
#  '， 小明 吃': 59573219,
#  '小明 吃 了': 34963440,
#  '吃 了 ，': 30680527,
#  '了 ， 小': 24014967,
#  '， 小 李': 59568498,
#  '小 李 吃': 34886176,
#  '李 吃 了': 42063419,
#  '吃 了 。': 30679547,
#  '了 。 来源': 23824623,
#  '1 ） 他们': 7770311,
#  '） 他们 一共': 56802340,
#  '他们 一共 吃': 24917101,
#  '一共 吃 了': 20551441,
#  '吃 了 这个': 30680348,
#  '了 这个 饼': 23993933,
#  '这个 饼 的': 53355322,
#  '饼 的 几分': 55389465,
#  '的 几分 之': 45690248,
#  '几分 之 几': 27618549,
#  '之 几 ？': 23478896,
#  '几 ？ \n': 27591740,
#  '？ \n （': 63240961,
#  '2 ） 还': 8853994,
#  '） 还 剩下': 57132789,
#  '还 剩下 几分': 53222107,
#  '剩下 几分 之': 28838478,
#  '？ \n 2': 63223828,
#  '2 、 用': 8700541,
#  '、 用 阴影': 18768519,
#  '用 阴影 画出': 44836933,
#  '阴影 画出 如下': 54691176,
#  '画出 如下 图形': 45114379,
#  '如下 图形 的': 33665470,
#  '图形 的 ，': 32059739,
#  '的 ， 画出': 47419182,
#  '， 画出 两种': 60625705,
#  '画出 两种 不同': 45112202,
#  '两种 不同 分': 22296807,
#  '不同 分 法': 21579151,
#  '分 法 。': 27882063,
#  '法 。 \n': 43556580,
#  '。 \n 3': 19073170,
#  '3 、 红': 9374222,
#  '、 红 金鱼': 18830727,
#  '红 金鱼 3': 49277565,
#  '金鱼 3 条': 54290482,
#  '3 条 ，': 9416539,
#  '条 ， 黄金': 42112837,
#  '， 黄金 鱼': 61348696,
#  '黄金 鱼 4': 55580718,
#  '鱼 4 条': 55554014,
#  '4 条 ，': 9783014,
#  '条 ， 其余': 42111915,
#  '， 其余 的': 58744929,
#  '其余 的 是': 27238814,
#  '的 是 黑': 46531507,
#  '是 黑 金鱼': 41218069,
#  '黑 金鱼 。': 55584101,
#  '金鱼 。 \n': 54290505,
#  '。 \n 请': 19250620,
#  '\n 请 你': 1747417,
#  '请 你 提出': 52313007,
#  '你 提出 有关': 25717569,
#  '提出 有关 分数': 39280466,
#  '有关 分数 的': 41736328,
#  '分数 的 数学': 28066471,
#  '的 数学 问题': 46422242,
#  '数学 问题 并': 39911597,
#  '问题 并 解决': 54563407,
#  '并 解决 。': 36126298,
#  '解决 。 \n': 51554323,
#  '    ？': 2403146,
#  '  ？ \n': 4576060,
#  '3 ）  ': 9433888,
#  '？ \n 第六': 63239243,
#  '\n 第六 单元测试': 1636740,
#  '第六 单元测试 卷': 48710092,
#  '单元测试 卷 的': 29389160,
#  '卷 的 部分': 29600264,
#  '的 部分 答案': 47228754,
#  '部分 答案 ：': 53983930,
#  '答案 ： \n': 48961661,
#  '： \n 一': 62154300,
#  '一 、 \n': 20348299,
#  '、 \n 二': 18042378,
#  '二 、 ×': 24115179,
#  '、 ×  ': 18165670,
#  '×   √': 16711930,
#  '  √  ': 3999715,
#  '√   ×': 17125037,
#  '  ×  ': 3985482,
#  '×   ×': 16711698,
#  '  √ \n': 3999567,
#  '√ \n 三': 17123917,
#  '三 、 1': 20934991,
#  '、 1 、': 18070817,
#  '1 、 （': 7664824,
#  '、 （ 1': 18997501,
#  '）   （': 56601190,
#  '  （ 2': 4459405,
#  '  （ 3': 4469291,
#  '3 ） \n': 9432811,
#  '2 、 ﹥': 8702433,
#  '、 ﹥  ': 18996563,
#  '﹥   ﹥': 55800282,
#  '  ﹥  ': 4449017,
#  '﹥   =': 55800135,
#  '=   =': 10771718,
#  '=   ﹥': 10777147,
#  '﹥   ﹤': 55800202,
#  '  ﹤  ': 4448727,
#  '﹤   ﹥': 55799330,
#  '  ﹥ \n': 4448976,
#  '﹥ \n 3': 55800064,
#  '3 、  ': 9366376,
#  '、   1': 18044200,
#  '  1  ': 2558814,
#  '1   0': 7457854,
#  '  0 \n': 2541914,
#  '0 \n 四': 7206104,
#  '四 、 1': 31727033,
#  '北师大 版 小学 三年级': 29165955,
#  '版 小学 三年级 下册': 44338825,
#  '小学 三年级 下册 数学': 34922901,
#  '三年级 下册 数学 第六': 20997753,
#  '下册 数学 第六 单元': 21347269,
#  '数学 第六 单元 《': 39909294,
#  '第六 单元 《 认识': 48709993,
#  '单元 《 认识 分数': 29387402,
#  '《 认识 分数 》': 19890295,
#  '认识 分数 》 单元测试': 51868634,
#  '分数 》 单元测试 3': 28059543,
#  '》 单元测试 3 （': 19906171,
#  '单元测试 3 （ 附': 29389009,
#  '3 （ 附 答案': 9432614,
#  '（ 附 答案 ）': 56440080,
#  '附 答案 ） \n': 54714110,
#  '答案 ） \n 一': 48959240,
#  '） \n 一 、': 56552179,
#  '\n 一 、 用': 1099830,
#  '一 、 用 分数': 20357640,
#  '、 用 分数 表示': 18767064,
#  '用 分数 表示 下面': 44795001,
#  '分数 表示 下面 每个': 28067056,
#  '表示 下面 每个 图里': 51026442,
#  '下面 每个 图里 的': 21400932,
#  '每个 图里 的 阴影': 42976132,
#  '图里 的 阴影 部分': 32105818,
#  '的 阴影 部分 。': 47302520,
#  '阴影 部分 。 （': 54691497,
#  '部分 。 （ 每空': 53969715,
#  '。 （ 每空 2': 19853338,
#  '（ 每空 2 分': 56406886,
#  '每空 2 分 ，': 43029022,
#  '2 分 ， 共': 8728583,
#  '分 ， 共 12': 27955631,
#  '， 共 12 分': 58698232,
#  '共 12 分 ）': 26964955,
#  '12 分 ） \n': 8129747,
#  '分 ） \n 二': 27898055,
#  '） \n 二 、': 56555465,
#  '\n 二 、 判断题': 1156184,
#  '二 、 判断题 。': 24117657,
#  '、 判断题 。 （': 18356933,
#  '判断题 。 （ 对': 28554641,
#  '。 （ 对 的': 19852337,
#  '（ 对 的 在': 56378433,
#  '对 的 在 括号': 34634067,
#  '的 在 括号 里': 45954886,
#  '在 括号 里 打': 32397612,
#  '括号 里 打 "': 38895725,
#  '里 打 " √': 54137436,
#  '打 " √ "': 38435897,
#  '" √ " ，': 4695585,
#  '√ " ， 错': 17126126,
#  '" ， 错 的': 5443394,
#  '， 错 的 打': 61281803,
#  '错 的 打 "': 54375130,
#  '的 打 " ×': 46353889,
#  '打 " × "': 38435530,
#  '" × " 。': 4693909,
#  '× " 。 ）': 16712880,
#  '" 。 ） （': 4741265,
#  '。 ） （ 每空': 19856623,
#  '） （ 每空 2': 57172558,
#  '分 ， 共 10': 27955420,
#  '， 共 10 分': 58697701,
#  '共 10 分 ）': 26963150,
#  '10 分 ） \n': 7996557,
#  '分 ） \n 1': 27888618,
#  '） \n 1 、': 56503000,
#  '\n 1 、  ': 313895,
#  '1 、   是': 7654262,
#  '、   是 表示': 18052828,
#  '  是 表示 阴影': 4302731,
#  '是 表示 阴影 部分': 41180758,
#  '表示 阴影 部分 的': 51051147,
#  '阴影 部分 的 分数': 54692275,
#  '部分 的 分数 。': 53980328,
#  '的 分数 。  ': 45705539,
#  '分数 。   （': 28059457,
#  '。   （  ': 19289186,
#  '  （   ）': 4450601,
#  '（   ） \n': 55834827,
#  '  ） \n 2': 4496436,
#  '） \n 2 、': 56513913,
#  '\n 2 、 同': 409828,
#  '2 、 同 分母': 8697818,
#  '、 同 分母 分数': 18410148,
#  '同 分母 分数 相加': 30820444,
#  '分母 分数 相加 减': 28162074,
#  '分数 相加 减 ，': 28066776,
#  '相加 减 ， 分母': 47732784,
#  '减 ， 分母 不变': 27557141,
#  '， 分母 不变 ，': 58818775,
#  '分母 不变 ， 分子': 28161048,
#  '不变 ， 分子 相加': 21567077,
#  '， 分子 相加 减': 58815691,
#  '分子 相加 减 。': 28029503,
#  '相加 减 。  ': 47732701,
#  '减 。   （': 27552855,
#  '  ） \n 3': 4497072,
#  '） \n 3 、': 56519750,
#  '\n 3 、 ＋': 474791,
#  '3 、 ＋  ': 9375315,
#  '、 ＋   =': 19002068,
#  '＋   =  ': 57287191,
#  '  =   （': 2774152,
#  '=   （  ': 10777201,
#  '  ） \n 4': 4497541,
#  '） \n 4 、': 56522214,
#  '\n 4 、  ': 502343,
#  '4 、   如': 9742872,
#  '、   如 左图': 18050169,
#  '  如 左图 长方形': 4216854,
#  '如 左图 长方形 的': 33655172,
#  '左图 长方形 的 与': 35516242,
#  '长方形 的 与 正方形': 54477949,
#  '的 与 正方形 的': 45361422,
#  '与 正方形 的 一样': 21955872,
#  '正方形 的 一样 大': 42810799,
#  '的 一样 大 。': 45322960,
#  '一样 大 。  ': 20723157,
#  '大 。   （': 33283843,
#  '  ） \n 5': 4497944,
#  '） \n 5 、': 56523869,
#  '\n 5 、 有': 527097,
#  '5 、 有 12': 10014924,
#  '、 有 12 个球': 18682641,
#  '有 12 个球 ，': 41572809,
#  '12 个球 ， 拿出': 8126557,
#  '个球 ， 拿出 ，': 22492098,
#  '， 拿出 ， 应该': 60027574,
#  '拿出 ， 应该 拿': 38912495,
#  '， 应该 拿 3': 59694256,
#  '应该 拿 3 个': 36247408,
#  '拿 3 个 。': 38906029,
#  '3 个 。  ': 9378024,
#  '个 。   （': 22379310,
#  '  ） \n 三': 4503627,
#  '） \n 三 、': 56553719,
#  '\n 三 、 填空题': 1118907,
#  '三 、 填空题 。': 20939340,
#  '、 填空题 。 （': 18453783,
#  '填空题 。 （ 第': 33009366,
#  '。 （ 第 1': 19853887,
#  '（ 第 1 题': 56419373,
#  '第 1 题 12': 48620968,
#  '1 题 12 分': 7730006,
#  '题 12 分 ，': 55262171,
#  '12 分 ， 第': 8136391,
#  '分 ， 第 2': 27963370,
#  '， 第 2 题': 60736698,
#  '第 2 题 16': 48625015,
#  '2 题 16 分': 8762315,
#  '题 16 分 ，': 55262298,
#  '16 分 ， 第': 8300546,
#  '分 ， 第 3': 27963697,
#  '， 第 3 题': 60737375,
#  '第 3 题 24': 48628596,
#  '3 题 24 分': 9427613,
#  '题 24 分 ，': 55262538,
#  '24 分 ， 共': 9126222,
#  '分 ， 共 52': 27958559,
#  '， 共 52 分': 58703388,
#  '共 52 分 ）': 26976668,
#  '52 分 ） \n': 10134812,
#  '\n 1 、 \n': 313759,
#  '1 、 \n （': 7653959,
#  '、 \n （ 1': 18043436,
#  '\n （ 1 ）': 1782833,
#  '（ 1 ）  ': 55890273,
#  '1 ）   的': 7745172,
#  '）   的 个数': 56600065,
#  '  的 个数 点': 4351090,
#  '的 个数 点 全部': 45391496,
#  '个数 点 全部 的': 22483382,
#  '点 全部 的 。': 44119867,
#  '全部 的 。 \n': 26776728,
#  ...}

# %% [markdown]
# # Test

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from tabulate import tabulate

# %%
def predict_with_threshold(model, X, threshold=0.98):
    probabilities = model.predict_proba(X)
    
    positive_probabilities = probabilities[:, 1]
    
    predictions = (positive_probabilities > threshold).astype(int)
    
    return predictions

# %%
test_dataset = datadict["test"]

# %%
test_dataset = test_dataset.map(dataset_map_pre_process)
# Out:
# Loading cached processed dataset at /home/ran/WorkSpace/my_Exam-Question-Bank-Dataset-zh_mnbvc/notebook/dataset/test/cache-50aac81089b34e9b.arrow

# %%
import time

start_time = time.time()

predictions = predict_with_threshold(model, test_dataset["text"])

print(f"time { time.time() - start_time}")
# Out:
# time 23.28389811515808

# %%
accuracy = accuracy_score(test_dataset["label"], predictions)
recall = recall_score(test_dataset["label"], predictions)
precision = precision_score(test_dataset["label"], predictions)
f1 = f1_score(test_dataset["label"], predictions)

# %%
data = [["Accuracy", accuracy], ["Recall", recall], ["Precision", precision], ["F1 Score", f1]]

print(tabulate(data, headers=["Metric", "Score"]))
# Out:
# Metric        Score
# ---------  --------
# Accuracy   0.992248
# Recall     0.990099
# Precision  0.995025
# F1 Score   0.992556

# %%
# threshold=0.5 and threshold=0.9
Metric        Score
---------  --------
Accuracy   0.989664
Recall     0.990099
Precision  0.990099
F1 Score   0.990099


# threshold=0.95（错误3个，全都是英语且没有明显特征或特征单一）
Metric        Score
---------  --------
Accuracy   0.992248
Recall     0.990099
Precision  0.995025
F1 Score   0.992556
# Out:
#   Cell In[626], line 1
#     Metric        Score
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Check

# %%
# 1："试卷" 0:“其他”
for index, prediction in enumerate(predictions):
    if test_dataset['label'][index] != prediction:
        print(f"{index}  预期:{test_dataset['label'][index]} -- 结果:{prediction}")
# Out:
# 11  预期:1 -- 结果:0
# 192  预期:1 -- 结果:0
# 386  预期:0 -- 结果:1

# %%
for line in test_dataset["text"][386].splitlines():
    print(line)
# Out:
# FREE高考英语词汇班
# 151 vr 曾经 h bs fl I hv vr s
# 强调极端概念  fr
#    o I w o s you ! /
# 152 uss 猜 随意 错误率高
# 153 hr 听到 状态
# ls o 听 动作
# 154 hur v 伤害 hur o's fl
# v 疼痛
# My h s . 受伤 hur / jur j 受伤的
# My h . 疼
# sh jur sb = sb s jur jury / hur  伤口
# 155  o o sh 打算做某事
# o 打算 意图 未发生
# 156 sk 任务 一次性
# uy 职责 长期性
# job / work 工作 该做的事 责任
# crr 职业 rofsso / jor 专业
# 157 rch v 到达 触及  能够到达/触及的地方
# wh y rch 力所能及
# byo y rch 力所不能及
# rch ou o ohrs = v sb  h 伸出援手
# 158 原因 rsul  结果 My ffors rsul  y succss.
# 结果 rsul fro 原因 My succss rsul fro y ffors.
# rso / rsul因果 cus / ffc 因果
# 159 s 台阶 脚步 步骤 s by s
# 160 sb suffr fro sh 某人遭受某事 负 无被动
#  fro  srous sochch, h w o h clc.
# 161 聪明 clvr / sr / brh / brll / ws / ll
# Arfcl Illc / AI 人工智能
# 162 buy / urchs / cosu / s oy 购买
# cusor 顾客 cosur 消费者
# cosu -- cosuo 消费
# ssu -- ssuo 假想
# rsu -- rsuo 继续
# sll -- sol -- sol 出售
# 163 h -- h -- h 隐藏 看不见 h  sk
# bh r 在...后面 看不见 bh h sc
# 164 ju 跳 高度
# l 跃 远  b l  cooy
# b 节奏 hr b vry fs
# sk 跳过 略过 sk h ls
# 165 lo -- lh 长度 w -- wh 宽度
# hh -- hh 高度 wh -- wh 重量
# sur  寸法 规格
# 166 r -- whol 部分---整体
# Th cov    ws w ovr y lck of cofc.
# 167 ck u sh 捡起来 ck u sb 接送某人
# ck u y cofc / hlh = rcovr 恢复
# ck u kowl / sklls = lr 学习
# ck v 挑 slc / choos 区分
# 168 rwr 回报 报酬  rur 作为回报
# wr 奖励 优秀
# 169 shk hs 握手 shk h 摇头
# 170 s  痕迹 牌子 v 签名 sur / s u
# rk /v 2 = r /v
#  1 记号 s 2 得分  xcll / oor rk
# v 1 做记号 2 判分 rk h r
# rkr 记号笔 rrk /v 评价
# sh /v 叹息 负
# sl /v 信号 动态
# 171 sr 传播 范围广 sr -- sr -- sr
# x 延伸 长度 深度 xsv / xso
# x 扩张 广度 xsv / xso
# 172 sck  棍子 lsck / choscks
# v 粘住 sckr / scky
# 坚持 sck o sh
# b suck 被困住  hvy rffc /  roubl
# rss / rssc 坚持不懈cos ffors困难/努力
# ss o sh 固执己见 不改变
# sck o sh 坚持 原则/信念
# 173 vlu  价值 r vlu / vw of vlu
#  v 珍惜 rsur / chrsh
# vlubl v+bl-j 有价值的usful / rcous / worhy
# vlulss +lss-j 无价值的 uslss / olss
# vlubl j 无价的 正 frsh / ory
# 174 lo 沿着 线路
# 175 bhv v 做动作 bhvor  行为 lu  bhvor
# 176 cuous / cuo 谨慎 危险 r / rous
# 177 y 空的 表面现象
# vc 空闲的 性质 vlbl 可用的
# sr 空余的 sr oy /  / roo
# 178 fr / ufr 公平/不公平 得到
# frly / qu / vry 相当 正 rhr 相当 负
# 179 flly /  h  / vully 最后 过程结束
# 180 h o o sh 碰巧做某事 偶然/突发
# suly / cclly 突然
# 181 h h wb 在网络上造成影响
# h h ro / rvl / joury 旅行
# I suly h  h ... / = I suly occurr o  h ... 我突然想到...
# 182 l -- ly -- l -- ly 躺着 位于
# l -- l -- l -- ly 说谎 shosy
# ly -- l -- l -- ly 放置 ly s / l-off
# 183 lf 下---上 v sb  lf / cour 精神振作
# 184 clrly / obvously / rly显然+结论 重要标志
# 185 oulr / oulry 流行 人数多
# 186 ow /  rs / currly / oy 现在 对比过去
# 187 rov -- rovl 移除
# survv -- survvl 生存
# rov -- rovl 批准
# 188 k  o wh sb 预约某人
# 189  y o o sh 某人注意某物
#  focus o o sh 某人注意某物
#  rw o's o 某物引起某人注意
#  rc o's y /  cch o's y
# rcv / buful / ry / chr 美丽的
# lc of rss / ours rcos 景点
# 190 for  形式 wr for 表格 fll  h for
# v 形成 co o b
# forl j 正式的 forl wr
# csul j 随意的 csul wr
# 191 lo 独自 中
# loly 孤独 寂寞 负
# 192 rssur / srss / bur 压力
# 193 surly / xcly / crly / bsoluly / fly / of cours 当然 确定
# 194 s r 相对 fh s / s h wll
# oos v 反对 ooso / oos / oo
# 195 b / f 打败
# 196 clss 级别 Frs Clss clssfy / clssfco 分级
# 197 co -- coo -- cov -- coor
# 198 coc / lk 连接 A------B coco 羁绊
# ch 附加 AB ch 附件
# jo 加入 C=A+B jo our hs 新的整体 jo ffors 集体努力
# 199 r / rly / rss 渴望 急切 未发生
# 200 for xl / for sc / such s / lk 举例 忽略
# 201 xch 交换 往来 相互
# 202 xos v 暴露
# b xos o sh 被暴露在某物中 接触到某物
# I ws xos o  fsc worl of rs. / I xos yslf o urous books.
# 203 oloz / oloy 道歉
# forv / forvss 原谅
# 204 r -- rsso 允许
#  -- sso 允许进入
# sub -- subsso 提交
# 205 rs 举起 提出 抚养 动作
# rs 升起 涌上来 状态 surs / sus
# 206 rush hour 高峰时刻 速度快/数量多
# 207 l wh / solv / sl / rss 应对 解决
# soluo 解决方案 wy / ho / sur 方法
# 208  bro sl 灿烂的微笑
# 209 u 正负中
# 210 suo 外在状况 My suo s o oo.
# coo 内部条件 My coo s o oo.
# 211 fy 鉴定 身份/性质 fco / ID
# 212 luh  嘲笑 负
# 213 lh  光亮 rkss / sh 暗
# v 点燃 lh h cl / hs fc l
# lh -- l -- l
# 214 w / ovly 新事物 ovo / cro 创新
# rw 续期
# 215 oo / oor 好坏
# 216  o sh  o sh 倾向于 前肯后否
#  o sh  o sh 宁愿 前肯后否
# o sh  o sh 而不是 前肯后否
# rfrc  偏好
# 217 rl -- rlo -- rlv -- rlvs -- rlosh
#  clos rlosh / closly coc 紧密相关
