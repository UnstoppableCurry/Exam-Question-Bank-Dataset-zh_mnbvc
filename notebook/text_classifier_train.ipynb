# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
import joblib
import datasets

# %% [markdown]
# # Train

# %%
import re

def remove_image_string(input_string):
    pattern = r"!\[(.*?)\]\(.*?\)\{width=\".*?\" height=\".*?\"\}|!\[.*?\]\(.*?\)|\[.*?\]\{.*?\}"
    result = re.sub(pattern, "", input_string)
    return result

def is_all_chinese_or_english(text):
    for char in text:
        if not is_chinese_or_english(char):
            return False
    return True

def is_chinese_or_english(char):
    # 判断是否为中文
    if '\u4e00' <= char <= '\u9fff':
        return True
    # 判断是否为英文
    elif 'a' <= char.lower() <= 'z':
        return True
    else:
        return False

def remove_noise_character(input_string):
    pattern = r"[>*|image|data|media|png]"
    
    return re.sub(pattern, "", input_string)

def one_text_pre_process(text):
    precessed_text_split_lines = []
    
    for line in text.splitlines():
        remove_image_line = remove_image_string(line)

        if remove_image_line.strip() in ["", ">"]:
            continue

        remove_image_line = remove_noise_character(remove_image_line)
        precessed_text_split_lines.append(remove_image_line)
        
    return "\n".join(precessed_text_split_lines)

def pre_process(text_list):
    precessed_text_list = [one_text_pre_process(text) for text in text_list]
    return precessed_text_list

def dataset_map_pre_process(row):
    row["text"] = one_text_pre_process(row["text"])
    return row

# %%
import jieba


def chinese_tokenizer(text):
    tokens = jieba.cut(text)
    return list(filter(lambda x:is_all_chinese_or_english(x), tokens))


def train(dataset):
    vectorizer = CountVectorizer(tokenizer=chinese_tokenizer, ngram_range=(1, 2))
    classifier = LogisticRegression(max_iter=100, verbose=1)
    model = make_pipeline(vectorizer, classifier)
    
    model.fit(dataset["text"], dataset["label"])
    return model

# %%
# datadict = datasets.load_dataset("ranWang/test_paper_textClassifier")
datadict = datasets.load_from_disk("./new_classification_datasets")
datadict
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 387
#     })
#     train: Dataset({
#         features: ['text', 'label', 'file_path'],
#         num_rows: 9536
#     })
# })

# %%
train_dataset = datadict["train"]
train_dataset = train_dataset.map(dataset_map_pre_process)
# Out:
# Loading cached processed dataset at /home/ran/WorkSpace/my_Exam-Question-Bank-Dataset-zh_mnbvc/notebook/new_classification_datasets/train/cache-8919a8cbc5b95eb2.arrow

# %%
# 随机打乱
train_dataset = train_dataset.shuffle(42)
# 验证集大小
validation_size = int(len(train_dataset)/10)
validation_dataset = train_dataset.select(range(validation_size))
train_dataset = train_dataset.select(range(validation_size, len(train_dataset)))
# Out:
# Loading cached shuffled indices for dataset at /home/ran/WorkSpace/my_Exam-Question-Bank-Dataset-zh_mnbvc/notebook/new_classification_datasets/train/cache-677c5f9a11a51a13.arrow

# %%
train_dataset
# Out:
# Dataset({
#     features: ['text', 'label', 'file_path'],
#     num_rows: 8583
# })

# %%
model = train(train_dataset)
# Out:
# /home/ran/.local/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =      6398638     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.94928D+03    |proj g|=  1.82487D+05
#  This problem is unconstrained.
# At iterate   50    f=  1.28316D+02    |proj g|=  2.20646D+02
#
# At iterate  100    f=  5.98905D+01    |proj g|=  4.22555D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# *****    100    174      1     0     0   4.226D+01   5.989D+01
#   F =   59.890473429223839
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /home/ran/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.9min finished

# %%
joblib.dump(model, 'TextClassifie-full-final.pkl')
# Out:
# ['TextClassifie-full-final.pkl']

# %% [markdown]
# # 模型数据

# %%
print("模型方程: y = ", model.named_steps['logisticregression'].coef_, " * x + ", model.named_steps['logisticregression'].intercept_)

print("参数量: ", model.named_steps['logisticregression'].coef_.size + 1)
# Out:
# 模型方程: y =  [[-6.66293309e-02  2.37002310e-02 -1.40826367e-03 ... -1.49745354e-05
#   -1.50341050e-05 -1.06960967e-05]]  * x +  [-0.45084807]
# 参数量:  6398638

# %%
count_vectorizer = model.steps[0][1]

# %%
count_vectorizer.vocabulary_
# Out:
# {'悬疑': 3174349,
#  '韩国片': 6268712,
#  '蒙太奇': 5388607,
#  '解说': 5527963,
#  '文案': 3642459,
#  '清冷': 4324163,
#  '死寂': 4127655,
#  '的': 4621191,
#  '公寓': 1339274,
#  '里': 6059641,
#  '一': 283847,
#  '女子': 2488499,
#  '大白天': 2443299,
#  '依然': 1167779,
#  '躺': 5799151,
#  '在': 2257192,
#  '床上': 2940506,
#  '她': 2491894,
#  '形容': 3052059,
#  '颓废': 6312777,
#  '生': 4508471,
#  '无可': 3699414,
#  '恋': 3163329,
#  '但': 1082661,
#  '又': 1830044,
#  '必须': 3115343,
#  '活着': 4270523,
#  '年前': 2912645,
#  '女儿': 2487697,
#  '西珍': 5471710,
#  '被': 5452703,
#  '人': 898291,
#  '绑架': 5095030,
#  '杀害': 3944916,
#  '到': 1586463,
#  '现在': 4476309,
#  '还': 5870213,
#  '没': 4218797,
#  '找到': 3340973,
#  '凶手': 1484121,
#  '这': 5879006,
#  '是': 3768682,
#  '活下去': 4265430,
#  '唯一': 2145571,
#  '理由': 4496215,
#  '警察': 5543581,
#  '吴青浩带': 2068215,
#  '着': 4759207,
#  '一名': 325477,
#  '小': 2727533,
#  '警员': 5543518,
#  '上门': 456999,
#  '拜访': 3413009,
#  '当年': 3044093,
#  '吴青浩是': 2068217,
#  '绑架案': 5095119,
#  '负责人': 5699384,
#  '他们': 972819,
#  '客厅': 2645317,
#  '等候': 4950685,
#  '只见': 1934548,
#  '书架上': 768001,
#  '摆着': 3528897,
#  '大量': 2449113,
#  '精心': 5004569,
#  '保存': 1183009,
#  '调查': 5675723,
#  '资料': 5738369,
#  '吴青浩': 2068183,
#  '随手': 6203250,
#  '一翻': 372456,
#  '里面': 6062978,
#  '全是': 1311489,
#  '新闻报道': 3666219,
#  '看到': 4743043,
#  '嫌疑犯': 2541378,
#  '通辑': 5976062,
#  '画像': 4584973,
#  '他': 966233,
#  '内疚': 1424704,
#  '地合': 2295516,
#  '上': 431035,
#  '了': 775319,
#  '还有': 5876217,
#  '五天': 860827,
#  '西珍案': 5471725,
#  '就': 2758015,
#  '到达': 1597315,
#  '年': 2904628,
#  '追诉': 5941016,
#  '期': 3903339,
#  '届时': 2785858,
#  '警局': 5543808,
#  '将': 2715666,
#  '不再': 487609,
#  '追查': 5939479,
#  '此案': 4118618,
#  '意味着': 3196276,
#  '永远': 4191842,
#  '逍遥法外': 5962176,
#  '就算': 2770155,
#  '以后': 1010241,
#  '知道': 4776962,
#  '谁': 5670290,
#  '也': 756094,
#  '不会': 484485,
#  '法办': 4242709,
#  '没脸': 4226860,
#  '告诉': 2075703,
#  '妈妈': 2525389,
#  '期已': 3905470,
#  '只好': 1927010,
#  '代劳': 980993,
#  '由于': 4553163,
#  '对': 2677847,
#  '事件': 804372,
#  '记忆': 5577539,
#  '模糊': 4081495,
#  '和': 2092594,
#  '证据不足': 5608801,
#  '犯罪者': 4444034,
#  '过': 5843471,
#  '忏悔': 3118373,
#  '时间': 3745925,
#  '疯狂': 4597271,
#  '地': 2286051,
#  '搬': 3524632,
#  '下': 457990,
#  '所有': 3295723,
#  '一页': 385378,
#  '页': 6273271,
#  '翻': 5173920,
#  '那一': 6009588,
#  '字字': 2547909,
#  '一句句': 324476,
#  '如刀般': 2513357,
#  '刺': 1609053,
#  '心': 3099931,
#  '怎么': 3130787,
#  '会': 1057074,
#  '真的': 4754562,
#  '吗': 2050458,
#  '说': 5647469,
#  '被害者': 5458754,
#  '明明': 3754894,
#  '那么': 6010699,
#  '痛苦': 4606003,
#  '凭': 1482496,
#  '什么': 937658,
#  '放过': 3574137,
#  '无言以对': 3708378,
#  '从': 950276,
#  '那里': 6019066,
#  '离开': 4835343,
#  '心情': 3103902,
#  '抑郁': 3365318,
#  '来到': 3974915,
#  '沿江': 4237094,
#  '公路': 1346364,
#  '就是': 2764482,
#  '杀': 3944571,
#  '那时': 6016357,
#  '眼睁睁': 4758011,
#  '看见': 4748174,
#  '逃脱': 5951056,
#  '却': 1786137,
#  '无能为力': 3707909,
#  '一支': 340702,
#  '白花': 4614829,
#  '路边': 5790551,
#  '以为': 1002286,
#  '来过': 3981017,
#  '打电话': 3321467,
#  '询问': 5633605,
#  '后': 2030991,
#  '发现': 1876471,
#  '不是': 511530,
#  '可': 1938728,
#  '这里': 5907155,
#  '只有': 1929475,
#  '警方': 5544113,
#  '既然': 3712891,
#  '前': 1612030,
#  '两者': 600496,
#  '没人来': 4219861,
#  '剩': 1624074,
#  '前方': 1617711,
#  '不远处': 534165,
#  '有': 3856901,
#  '监控': 4693280,
#  '瞬间': 4769013,
#  '热血': 4392607,
#  '翻涌': 5174524,
#  '出现': 1500006,
#  '带': 2872824,
#  '查': 4009157,
#  '下午': 465256,
#  '直到': 4710440,
#  '晚上': 3805988,
#  '才': 3312064,
#  '黑夜': 6389458,
#  '放下': 3569146,
#  '那朵': 6016803,
#  '长时间': 6134241,
#  '低头': 1098194,
#  '沉思': 4214518,
#  '久久': 711110,
#  '盯': 4709423,
#  '虽然': 5403502,
#  '面目': 6262487,
#  '模糊不清': 4081671,
#  '激动': 4365580,
#  '地心': 2298244,
#  '都': 6035640,
#  '要': 5473563,
#  '跳': 5790856,
#  '出来': 1496795,
#  '连夜': 5931281,
#  '山上': 2797270,
#  '一片': 357495,
#  '空地': 4880656,
#  '果然': 3997424,
#  '一组': 371450,
#  '清晰': 4326518,
#  '轮胎': 5815156,
#  '印': 1771397,
#  '案发时': 4049739,
#  '把': 3356643,
#  '偷来': 1251137,
#  '车': 5800425,
#  '丢': 586649,
#  '这么': 5887709,
#  '说明': 5653254,
#  '中': 619685,
#  '那': 6007820,
#  '很': 3073370,
#  '可能': 1956160,
#  '很快': 3077865,
#  '展开': 2787858,
#  '追踪': 5941186,
#  '上司': 443779,
#  '责怪': 5711525,
#  '他办': 976714,
#  '旧案': 3724884,
#  '拒绝': 3406985,
#  '加': 1644653,
#  '派': 4271392,
#  '人手': 921051,
#  '只能': 1932341,
#  '根据': 4035799,
#  '大海捞针': 2442285,
#  '距': 5781954,
#  '个': 608252,
#  '小时': 2739478,
#  '人流': 928197,
#  '涌动': 4305382,
#  '市场': 2856094,
#  '那辆车': 6018918,
#  '追': 5938595,
#  '车主': 5801257,
#  '穿街': 4886061,
#  '走巷': 5756767,
#  '咫尺': 2124878,
#  '追不上': 5938810,
#  '一家': 333064,
#  '饭店': 6334556,
#  '仅': 941491,
#  '一桌': 350241,
#  '之遥': 738652,
#  '还是': 5873484,
#  '狡猾': 4449513,
#  '死死': 4127838,
#  '拼命': 3418502,
#  '推开': 3491932,
#  '拥挤': 3414831,
#  '撞倒': 3533689,
#  '看着': 4747762,
#  '开车': 3000822,
#  '记住': 5574664,
#  '车牌号': 5802489,
#  '最终': 3846701,
#  '证实': 5608078,
#  '车牌': 5802477,
#  '假': 1227524,
#  '至此': 5312691,
#  '线索': 5057839,
#  '再次': 1433274,
#  '中断': 650676,
#  '而': 5195852,
#  '无法': 3704212,
#  '原谅': 1814639,
#  '自己': 5290765,
#  '辞掉': 5832035,
#  '工作': 2813928,
#  '临走前': 664004,
#  '天': 2451976,
#  '台上': 1962959,
#  '点火': 4383687,
#  '烧掉': 4388323,
#  '听': 2061067,
#  '发来': 1875896,
#  '语音': 5645215,
#  '让': 5567976,
#  '帮忙': 2879002,
#  '几个': 1474821,
#  '地址': 2296071,
#  '这个': 5883849,
#  '母亲': 4132949,
#  '没有': 4220895,
#  '放弃': 3571652,
#  '追凶': 5938912,
#  '已经': 2849434,
#  '挂断': 3424703,
#  '天空': 2460139,
#  '突降': 4889900,
#  '大雨': 2451147,
#  '火焰': 4371172,
#  '浇灭': 4280258,
#  '也许': 761835,
#  '冥冥中': 1447782,
#  '自有': 5297198,
#  '天意': 2456877,
#  '此后': 4115657,
#  '度日': 2964800,
#  '整天': 3625718,
#  '睡得': 4765808,
#  '人事不知': 908312,
#  '不久': 482325,
#  '好友': 2499878,
#  '姜': 2534846,
#  '警官': 5543545,
#  '找上门来': 3340087,
#  '原来': 1811830,
#  '负责': 5696055,
#  '片区': 4417859,
#  '发生': 1879259,
#  '小女孩': 2735225,
#  '事情': 809521,
#  '经过': 5090761,
#  '这样': 5898067,
#  '一个': 298048,
#  '叫': 1934989,
#  '韩哲': 6268564,
#  '老人': 5176273,
#  '外孙女': 2394664,
#  '小春': 2741428,
#  '门外': 6140998,
#  '玩耍': 4468198,
#  '老': 5175501,
#  '韩': 6268396,
#  '听到': 2062222,
#  '家中': 2658490,
#  '电话响': 4580359,
#  '便': 1173022,
#  '回去': 2194633,
#  '接电话': 3480239,
#  '电话': 4579394,
#  '接到': 3476033,
#  '反而': 1860793,
#  '不见': 528876,
#  '报警': 3390854,
#  '监听': 4692632,
#  '绑匪': 5094935,
#  '来': 3970413,
#  '着急': 4764341,
#  '确认': 4805527,
#  '是否': 3796701,
#  '没事': 4219678,
#  '只': 1924662,
#  '明早': 3754887,
#  '准备': 1463428,
#  '好': 2494238,
#  '千万': 1727844,
#  '现金': 4484001,
#  '焦虑': 4396584,
#  '之下': 722234,
#  '倒': 1215149,
#  '地上': 2290924,
#  '大喘': 2429985,
#  '粗气': 4999725,
#  '女警察': 2490765,
#  '解开': 5522809,
#  '衣扣': 5430913,
#  '胸口': 5259186,
#  '一条': 346357,
#  '手术': 3307792,
#  '伤疤': 1076990,
#  '做': 1233786,
#  '心脏': 3108952,
#  '来自': 3978316,
#  '公园': 1337990,
#  '现场': 4478042,
#  '搜索': 3522258,
#  '除了': 6193731,
#  '一只': 324485,
#  '烟头': 4386948,
#  '外': 2390330,
#  '指纹': 3439494,
#  '清理': 4329524,
#  '点': 4379188,
#  '打来': 3320905,
#  '想': 3187632,
#  '垃圾车': 2322624,
#  '找': 3339320,
#  '答案': 4958348,
#  '一袋': 377575,
#  '袋': 5452071,
#  '垃圾': 2322022,
#  '翻找': 5174351,
#  '一张': 337425,
#  '照片': 4403343,
#  '孩子': 2573653,
#  '查找': 4010229,
#  '档案': 4051602,
#  '做案': 1242974,
#  '手法': 3309815,
#  '一模一样': 350623,
#  '案子': 4049788,
#  '登门': 4610869,
#  '请教': 5661093,
#  '吴青浩一': 2068213,
#  '断定': 3651879,
#  '同一': 2008478,
#  '他查': 977248,
#  '早就': 3726111,
#  '了然于心': 796035,
#  '寄给': 2669804,
#  '军用': 1441932,
#  '包': 1679468,
#  '准时': 1465218,
#  '送到': 5945264,
#  '火车': 4371870,
#  '龙山': 6397842,
#  '站': 4897768,
#  '当时': 3045095,
#  '正好': 4100222,
#  '一趟': 380215,
#  '下车': 472851,
#  '清一色': 4323632,
#  '当兵': 3041063,
#  '背上': 5252344,
#  '寄来': 2669702,
#  '同款': 2018784,
#  '同色': 2021019,
#  '扮成': 3334473,
#  '军人': 1441129,
#  '趁乱': 5767722,
#  '调包': 5672411,
#  '朝': 3901935,
#  '地铁': 2305456,
#  '反': 1853238,
#  '方向': 3669973,
#  '成功': 3223537,
#  '这边': 5906692,
#  '刚': 1558030,
#  '分析': 1526201,
#  '完': 2594968,
#  '交易': 871986,
#  '地点': 2301135,
#  '方式': 3672573,
#  '丝毫不差': 586203,
#  '立即': 4893928,
#  '车站': 5802743,
#  '布控': 2865366,
#  '赶往': 5759939,
#  '路上': 5788135,
#  '压根': 1799775,
#  '没想到': 4220600,
#  '劫匪': 1669661,
#  '能': 5259942,
#  '拿到': 3420348,
#  '钱': 6099582,
#  '因此': 2209787,
#  '提供': 3502803,
#  '假钞': 1230907,
#  '事发': 807566,
#  '上级': 452510,
#  '大怒': 2438913,
#  '命令': 2090348,
#  '警力': 5543186,
#  '追回': 5939127,
#  '留守': 4590214,
#  '西珍家': 5471722,
#  '被迫': 5459607,
#  '撤离': 3534203,
#  '等': 4941101,
#  '赶回': 5759870,
#  '时': 3727860,
#  '踪影': 5793389,
#  '录音': 3049996,
#  '给': 5108266,
#  '去': 1815631,
#  '此时': 4117387,
#  '派出': 4271860,
#  '多余': 2406861,
#  '轻松': 5820113,
#  '拿走': 3420928,
#  '至于': 5310374,
#  '具体': 1402353,
#  '拿': 3419398,
#  '死': 4126169,
#  '闭口不谈': 6143253,
#  '层层': 2781238,
#  '控': 3482900,
#  '全员': 1306757,
#  '戒备': 3253586,
#  '接下来': 3475631,
#  '一场': 327284,
#  '硬仗': 4798403,
#  '不敢': 508620,
#  '松懈': 3984698,
#  '故技重施': 3586503,
#  '器': 2171535,
#  '破坏': 4794818,
#  '所有人': 3298375,
#  '全力': 1305675,
#  '追击': 5938920,
#  '不': 476045,
#  '哪': 2135889,
#  '情况': 3175977,
#  '摸透': 3532744,
#  '逃出去': 5950859,
#  '车下': 5801241,
#  '生路': 4526267,
#  '沿着': 4237426,
#  '一阵': 384633,
#  '出': 1484820,
#  '之': 713770,
#  '一把': 339803,
#  '抱住': 3393622,
#  '扳': 3334953,
#  '脸': 5278332,
#  '竟然': 4902651,
#  '外公': 2392459,
#  '交代': 869388,
#  '当': 3035018,
#  '家里': 2663038,
#  '门口': 6140788,
#  '帮': 2877582,
#  '还原': 5872818,
#  '案发': 4049729,
#  '情状': 3182692,
#  '长椅': 6135953,
#  '休息': 1047201,
#  '手机': 3308034,
#  '铃声': 6104472,
#  '藏': 5396071,
#  '附近': 6180585,
#  '一部': 382643,
#  '接通': 3482792,
#  '叫喊': 1937187,
#  '窗外': 4891353,
#  '频频': 6312695,
#  '向': 2043649,
#  '招手': 3411082,
#  '却没能': 1788211,
#  '引起': 3011391,
#  '注意': 4254438,
#  '这时': 5895335,
#  '声音': 2371222,
#  '我': 3236636,
#  '手上': 3305254,
#  '按': 3440317,
#  '要求': 5481795,
#  '驱车': 6348935,
#  '林间': 3996037,
#  '一处': 328840,
#  '废弃': 2962152,
#  '仓库': 965009,
#  '传来': 1071891,
#  '进去': 5913571,
#  '检查': 4058646,
#  '竟是': 4902603,
#  '磁带': 4810406,
#  '锁住': 6117100,
#  '大门': 2450360,
#  '冲过去': 1452391,
#  '大喊大叫': 2429973,
#  '没人': 4219784,
#  '理会': 4492446,
#  '气冲冲': 4171285,
#  '摔掉': 3530429,
#  '录音机': 3050163,
#  '漆黑': 4357449,
#  '周围': 2082664,
#  '不到': 489311,
#  '死去': 4127468,
#  '不知': 519520,
#  '多久': 2405692,
#  '突然': 4888541,
#  '打开': 3319450,
#  '立马': 4897379,
#  '跑': 5781160,
#  '回': 2193213,
#  '车上': 5801168,
#  '字条': 2548265,
#  '上面': 457299,
#  '写': 1436454,
#  '穿': 4885163,
#  '军服': 1441786,
#  '以前': 1004794,
#  '导航仪': 2712714,
#  '设置': 5599523,
#  '迟': 5935073,
#  '一秒': 367968,
#  '就别': 2764218,
#  '见到': 5491904,
#  '随后': 6202355,
#  '收到': 3552348,
#  '一段': 354204,
#  '视频': 5512481,
#  '部手机': 6030068,
#  '汉江': 4203344,
#  '大桥': 2440891,
#  '应': 2944020,
#  '扔进': 3324121,
#  '承诺': 3348039,
#  '只要': 1933250,
#  '钱袋子': 6101095,
#  '扔': 3323965,
#  '出墙': 1494642,
#  '自然': 5298635,
#  '平安': 2896803,
#  '回家': 2195568,
#  '熄灭': 4404813,
#  '电话亭': 4580202,
#  '十分相似': 1724212,
#  '老家': 5178336,
#  '搜查': 3522088,
#  '正是': 4105116,
#  '拍下': 3405296,
#  '受害': 1897014,
#  '家属': 2660211,
#  '变成': 1906283,
#  '试图': 5624646,
#  '了解': 796089,
#  '为什么': 683123,
#  '失踪': 2471123,
#  '五个': 856905,
#  '解释': 5528293,
#  '爸爸': 4416721,
#  '觉得': 5513205,
#  '的话': 4685299,
#  '更难': 3829949,
#  '平家': 2897044,
#  '如此': 2521033,
#  '熟悉': 4406129,
#  '由此': 4558264,
#  '认定': 5561684,
#  '韩有': 6268860,
#  '重大': 6066591,
#  '嫌疑': 2541275,
#  '怀疑': 3128606,
#  '供词': 1163184,
#  '捡': 3458582,
#  'dna': 100944,
#  '相符': 4732149,
#  '铁证如山': 6103580,
#  '委屈': 2533355,
#  '巴巴': 2852580,
#  '地向': 2295607,
#  '指使': 3429613,
#  '希望': 2868547,
#  '快点': 3124970,
#  '破案': 4795694,
#  '相信': 4720900,
#  '认为': 5557951,
#  '鸭子': 6380772,
#  '嘴硬': 2171021,
#  '一直': 361698,
#  '旁边': 3690429,
#  '观看': 5498267,
#  '进展': 5915089,
#  '提醒': 3515172,
#  '因为': 2203561,
#  '细心': 5070337,
#  '擦掉': 3543078,
#  '丢下': 586734,
#  '摆明': 3528772,
#  '故意': 3586196,
#  '误导': 5645911,
#  '而且': 5205004,
#  '孙女': 2555995,
#  '动机': 1663855,
#  '身': 5794160,
#  '何处': 1112015,
#  '种种': 4842770,
#  '问题': 6147176,
#  '解决': 5519262,
#  '肯定': 5246688,
#  '推测': 3492558,
#  '暗中': 3816956,
#  '观察': 5494550,
#  '韩骗': 6269064,
#  '进': 5908671,
#  '禁足': 4830934,
#  '趁': 5767660,
#  '段时间': 4131215,
#  '拍': 3405012,
#  '栽赃': 4046434,
#  '然后': 4397791,
#  '用': 4527302,
#  '方法': 3678338,
#  '受害者': 1897063,
#  '索要': 5022573,
#  '赎金': 5748253,
#  '不同': 494027,
#  '这次': 5900403,
#  '韩当': 6268754,
#  '替罪羊': 3835476,
#  '抓老': 3368228,
#  '韩时': 6268848,
#  '往外': 3068525,
#  '墙外': 2356206,
#  '一听': 326181,
#  '火': 4369473,
#  '嘲讽': 2170629,
#  '嫉妒': 2541052,
#  '破': 4794371,
#  '大案': 2440874,
#  '当场': 3043086,
#  '发飙': 1887446,
#  '作为': 1120139,
#  '应该': 2955707,
#  '寻求': 2707768,
#  '真相': 4755148,
#  '独自': 4452084,
#  '行动': 5422019,
#  '那间': 6019652,
#  '摔碎': 3530447,
#  '专门': 563064,
#  '处理': 2377240,
#  '老朋友': 5180405,
#  '修复': 1208491,
#  '关于': 1364815,
#  '所言': 3301765,
#  '录音带': 3050112,
#  '交给': 875986,
#  '重新': 6069097,
#  '对方': 2698380,
#  '直接': 4711825,
#  '垃圾桶': 2322496,
#  '盖棺定论': 4698590,
#  '事': 801089,
#  '媒体报道': 2540616,
#  '大家': 2435056,
#  '为此': 687675,
#  '欣然自喜': 4089806,
#  '粗暴': 4999654,
#  '杀死': 3945105,
#  '尸体': 2771853,
#  '掉': 3464139,
#  '再': 1429594,
#  '辩驳': 5834376,
#  '音频': 6271071,
#  '办法': 1638185,
#  '模仿': 4076952,
#  '改变': 3560615,
#  '心中': 3101272,
#  '疑惑': 4595010,
#  '偷偷': 1250886,
#  '拷贝': 3418075,
#  '检测': 4061226,
#  '通过': 5976139,
#  '多次': 2413446,
#  '对比': 2700031,
#  '十五年': 1720447,
#  '相匹配': 4724167,
#  '录制': 3049528,
#  '进行': 5918198,
#  '震惊': 6243055,
#  '留言': 4591015,
#  '上次': 448688,
#  '一半': 322884,
#  '关掉': 1369051,
#  '一次': 350684,
#  '耐心': 5213763,
#  '惊': 3184299,
#  '怕': 3133453,
#  '心思': 3103689,
#  '缜密': 5142333,
#  '疏忽': 4594052,
#  '导致': 2710561,
#  '走向': 5756243,
#  '不归路': 503548,
#  '其实': 1398185,
#  '猜测': 4454235,
#  '并': 2920156,
#  '错': 6118824,
#  '那天': 6015846,
#  '亲眼看到': 897728,
#  '像': 1256439,
#  '一样': 348131,
#  '米肠店': 4992179,
#  '打听': 3318798,
#  '消息': 4297174,
#  '意外': 3197305,
#  '留下': 4589158,
#  '雨伞': 6227377,
#  '得知': 3092296,
#  '储蓄银行': 1253556,
#  '高级': 6369851,
#  '客户': 2645643,
#  '参加': 1824482,
#  '某次': 4005828,
#  '活动': 4266029,
#  '奖品': 2482396,
#  '用钱': 4544741,
#  '贿赂': 5736112,
#  '银行职员': 6109336,
#  '信息': 1200656,
#  '这时候': 5895937,
#  '发': 1862856,
#  '吴青浩请': 2068220,
#  '回音': 2200615,
#  '挨': 3451877,
#  '走访': 5757437,
#  '凭着': 1483030,
#  '不懈': 507646,
#  '努力': 1668303,
#  '家庭': 2660487,
#  '相册': 4723650,
#  '正在': 4099213,
#  '住院': 1101846,
#  '墙上': 2355943,
#  '日历': 3717683,
#  '到期': 1596393,
#  '日子': 3718140,
#  '重点': 6070472,
#  '标记': 4021246,
#  '那一刻': 6009615,
#  '积压': 4855923,
#  '仇恨': 943350,
#  '终于': 5073900,
#  '发泄': 1875981,
#  '对象': 2704533,
#  '靠': 6256116,
#  '犹豫': 4447818,
#  '一下': 296155,
#  '举起': 709687,
#  '首': 6338038,
#  '一刀': 319322,
#  '下去': 465864,
#  '仇': 943293,
#  '报': 3384409,
#  '一脸': 372854,
#  '幸福': 2929061,
#  '抱': 3393507,
#  '欢声笑语': 4089019,
#  '怒': 3133210,
#  '终生': 5075473,
#  '忍受': 3118136,
#  '丧女': 608089,
#  '之痛': 736017,
#  '如果': 2516698,
#  '世界': 568628,
#  '公平': 1340023,
#  '就让': 2771278,
#  '制造': 1606542,
#  '身心俱疲': 5797540,
#  '悄然': 3170639,
#  '心里': 3109997,
#  '愈发': 3193356,
#  '坚定': 2316200,
#  '付出': 977967,
#  '更': 3822028,
#  '惨痛': 3186524,
#  '代价': 980243,
#  '为了': 681323,
#  '救': 3594138,
#  '生病': 4525556,
#  '勒索钱财': 1676684,
#  '嫁祸': 2540984,
#  '任': 1030264,
#  '你': 1132910,
#  '心知': 3108413,
#  '无从': 3697830,
#  '宝贝': 2619049,
#  '恨': 3166552,
#  '一辈子': 381192,
#  '这是': 5896086,
#  '比': 4145749,
#  '坐牢': 2314266,
#  '残酷': 4129619,
#  '精神': 5005940,
#  '惩罚': 3186856,
#  '海边': 4294232,
#  '小院': 2748999,
#  '悉心照料': 3170848,
#  '不该': 530448,
#  '可是': 1951245,
#  '怎样': 3132250,
#  '办案': 1638080,
#  '不利': 488895,
#  '抓': 3365684,
#  '日日夜夜': 3719965,
#  '锥心': 6123743,
#  '整整': 3627156,
#  '不休': 484444,
#  '不止': 516358,
#  '逼': 5990624,
#  '悔过': 3170990,
#  '期到': 3905352,
#  '做错': 1244108,
#  '就要': 2770539,
#  '付出代价': 978219,
#  '这才': 5894929,
#  '王道': 4466441,
#  '呢': 2079463,
#  '赶紧': 5760151,
#  '可西珍': 1959581,
#  '坚持': 2317299,
#  '为': 664626,
#  '苦苦哀求': 5347726,
#  '半路上': 1736646,
#  '陷入': 6199970,
#  '法律': 4244617,
#  '正义': 4097752,
#  '忽然': 3127342,
#  '变得': 1905561,
#  '不可': 492122,
#  '调和': 5672546,
#  '到底': 1595939,
#  '该': 5633963,
#  '如何': 2511317,
#  '选择': 5955519,
#  '索性': 5022393,
#  '监狱': 4694370,
#  '约见': 5044319,
#  '不想': 506791,
#  '承认': 3347561,
#  '一步步': 354113,
#  '揭穿': 3520893,
#  '犯罪': 4443635,
#  '行径': 5423726,
#  '我们': 3242823,
#  '看清': 4746759,
#  '那个': 6009675,
#  '案件': 4048549,
#  '情节': 3183712,
#  '那晚': 6016534,
#  '约': 5041557,
#  '见面': 5493454,
#  '头上': 2471831,
#  '套上': 2483971,
#  '塑料袋': 2349545,
#  '他开': 977010,
#  '箱子': 4987157,
#  '勇敢': 1675524,
#  '偷袭': 1251333,
#  '反抗': 1858880,
#  '趁机': 5767753,
#  '逃进': 5951239,
#  '树林': 4024535,
#  '紧追不舍': 5025814,
#  '最后': 3839914,
#  '失足': 2471103,
#  '跌落': 5781104,
#  '山坡': 2798279,
#  '赶来': 5760102,
#  '诡异': 5633325,
#  '操作': 3539459,
#  '满脸': 4353233,
#  '惊愕': 3184893,
#  '偏偏': 1231388,
#  '从天而降': 960508,
#  '猛打': 4453717,
#  '方向盘': 3671590,
#  '翻车': 5175116,
#  '被困': 5458620,
#  '动弹不得': 1662715,
#  '查看': 4010981,
#  '哭': 2139146,
#  '得': 3081943,
#  '撕心裂肺': 3533538,
#  '趁此机会': 5767794,
#  '气愤': 4172456,
#  '拍桌子': 3406196,
#  '时至今日': 3744877,
#  '绝望': 5115510,
#  '哭声': 2139322,
#  '犹在': 4447481,
#  '耳畔': 5216372,
#  '不屑': 502684,
#  '献花': 4455757,
#  '既': 3711357,
#  '祈祷': 4823246,
#  '求西珍': 4198318,
#  '而是': 5209565,
#  '庆祝': 2940188,
#  '新生': 3662743,
#  '躲过': 5799039,
#  '法律制裁': 4245883,
#  '无耻': 3707721,
#  '开脱': 3000303,
#  '底气十足': 2958627,
#  '赎罪': 5748237,
#  '毫无': 4162644,
#  '之意': 732102,
#  '认罪': 5563925,
#  ...}

# %% [markdown]
# # Test

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from tabulate import tabulate

# %%
def predict_with_threshold(model, X, threshold=0.5):
    probabilities = model.predict_proba(X)
    
    positive_probabilities = probabilities[:, 1]

    predictions = (positive_probabilities > threshold).astype(int)
    
    return predictions, positive_probabilities

# %%
# test_dataset = datadict["test"]
test_dataset = validation_dataset

# %%
test_dataset = test_dataset.map(dataset_map_pre_process)
# Out:
# Loading cached processed dataset at /home/ran/WorkSpace/my_Exam-Question-Bank-Dataset-zh_mnbvc/notebook/new_classification_datasets/train/cache-05027825d2f02e0a.arrow

# %%
import time

start_time = time.time()

predictions, positive_probabilities = predict_with_threshold(model, test_dataset["text"])

print(f"time { time.time() - start_time}")
# Out:
# time 16.69502592086792

# %%
accuracy = accuracy_score(test_dataset["label"], predictions)
recall = recall_score(test_dataset["label"], predictions)
precision = precision_score(test_dataset["label"], predictions)
f1 = f1_score(test_dataset["label"], predictions)

# %%
data = [["Accuracy", accuracy], ["Recall", recall], ["Precision", precision], ["F1 Score", f1]]

print(tabulate(data, headers=["Metric", "Score"]))
# Out:
# Metric        Score
# ---------  --------
# Accuracy   0.983211
# Recall     0.961415
# Precision  0.986799
# F1 Score   0.973941

# %% [markdown]
# # Check

# %%
# 按照0.5threshold判断是否为试卷
for index, prediction in enumerate(predictions):
    if test_dataset['label'][index] != prediction:
        scope = '{:.2f}'.format(positive_probabilities[index])
        print(f"{index} -- {scope} -- {test_dataset['file_path'][index]}")
# Out:
# 31 -- 0.12 -- positive_file/b08高考冲刺八：地理图像技能（一）.doc
# 65 -- 0.18 -- positive_file/必修1 第二单元 单元滚动练(二).docx
# 125 -- 1.00 -- negative_file/contents of002、忏悔录.doc
# 232 -- 0.17 --
# 245 -- 0.33 -- positive_file/1高考冲刺：化学实验仪器.doc
# 308 -- 0.18 -- positive_file/02.doc
# 383 -- 0.56 -- negative_file/45美国期望的各年龄段阅读水平.docx
# 402 -- 0.22 --
# 510 -- 0.33 -- positive_file/b09高考冲刺九：地理图像技能（二）.doc
# 513 -- 0.49 --
# 553 -- 0.08 -- positive_file/公考遴选每日考题10道（2023年2月8日）【官方抖音号：资深秘书】.docx
# 599 -- 0.00 -- positive_file/2023年“安全生产月”主题知识竞赛测试题（附答案）【官方抖音号：资深秘书】.docx
# 683 -- 0.39 --
# 874 -- 0.77 -- negative_file/初中地理思维导图20组.docx
# 930 -- 0.98 -- negative_file/3_页面设置-A4纸与黄金分割.doc
# 943 -- 0.00 --

# %%
for line in test_dataset["text"][943].splitlines():
    print(line)
# Out:
# 2019年"中南传媒湖南新教材杯"重庆市高中数学竞赛
# 暨全国高中数学联赛（重庆赛区）预赛试题参考答案
# 一、填空题(每小题8分，共64分)
# 1.设为三元集合（三个不同实数组成的集合），集合，若，则集合\_\_\_\_\_\_\_\_.
# 答案：
# 提示：设，其中
# 则解得，从而。
# 2.函数$f\lf( x \rh) = (\sqr{1 + x} + \sqr{1 - x} - 3)(\sqr{1 - x^{2}} + 1)$的最小值为$$，最大值为$M$，则$\frc{M}{} =$\_\_\_\_\_\_\_\_.
# 答案： $\frc{3 - \sqr{2}}{2}$
# 提示：设$ = \sqr{1 + x} + \sqr{1 - x}$,则$ \q 0$且$^{2} = 2 + 2\sqr{1 - x^{2}}$，∴$ \ \lf\lbrck \sqr{2},2 \rh\rbrck$.
# $f\lf( x \rh) = \lf(  - 3 \rh) \co \frc{^{2}}{2}$，令$\lf(  \rh) = \frc{1}{2}^{2}\lf(  - 3 \rh)$，$ \ \lbrck\sqr{2},2\rbrck$.
# 令$^{'}\lf(  \rh) = 0$得$ = 2$，$\lf( \sqr{2} \rh) = \sqr{2} - 3$，$\lf( 2 \rh) = - 2$，
# ∴$M = {\lf(  \rh)}_{\x} = \sqr{2} - 3$，$ = {\lf(  \rh)}_{\} = - 2$，∴$\frc{M}{} = \frc{3 - \sqr{2}}{2}$.
# 3.$\ 15^{o} + 2\sqr{2}\s 15^{o} =$\_\_\_\_\_\_\_\_.
# 答案： $1$
# 提示：$\ 15^{o} + 2\sqr{2}\s 15^{o} = \frc{{\x{s}}15^{o}}{\cos 15^{o}} + 2\sqr{2}\s 15^{o} = \frc{{\x{s}}15^{o} + \sqr{2}\s 30^{o}}{\cos 15^{o}} = \frc{{\x{s}}15^{o} + \sqr{2}\s\lf( 45^{o} - 15^{o} \rh)}{\cos 15^{o}}$
# $= \frc{{\x{s}}15^{o} + \sqr{2}(\s 45^{o}\cos 15^{o} - \cos 45^{o}\s 15^{o})}{\cos 15^{o}} = 1$.
# 4.已知向量$\ovrrhrrow{}$，$\ovrrhrrow{b}$，$\ovrrhrrow{c}$满足$\lf \ovrrhrrow{} \rh : \lf \ovrrhrrow{b} \rh : \lf \ovrrhrrow{c} \rh = 1 : k : 3(k \ \hbf{Z}^{+})$，且$\ovrrhrrow{b} - \ovrrhrrow{} = 2(\ovrrhrrow{c} - \ovrrhrrow{b})$，若$\lh$为$\ovrrhrrow{}$，$\ovrrhrrow{c}$的夹角，则$\cos\lh =$\_\_\_\_\_\_\_\_.
# 答案： $- \frc{1}{12}$
# 提示：∵$\ovrrhrrow{b} - \ovrrhrrow{} = 2(\ovrrhrrow{c} - \ovrrhrrow{b})$ ∴$\ovrrhrrow{b} = \frc{1}{3}\ovrrhrrow{} + \frc{2}{3}\ovrrhrrow{c}$ ∴${\ovrrhrrow{b}}^{2} = \frc{1}{9}{\ovrrhrrow{}}^{2} + \frc{4}{9}{\ovrrhrrow{c}}^{2} + \frc{4}{9}\ovrrhrrow{} \co \ovrrhrrow{c}$
# ∵$\lf \ovrrhrrow{} \rh : \lf \ovrrhrrow{b} \rh : \lf \ovrrhrrow{c} \rh = 1 : k : 3$ ∴$k^{2} = \frc{1}{9} + 4 + \frc{4}{3}\cos\lh \ (2,6)$
# 又∵$k \ \hbf{Z}^{+}$ ∴$k = 2$ ∴$\cos\lh = - \frc{1}{12}$.
# 5.已知复数$z_{1}$，$z_{2}$，$z_{3}$使得$\frc{z_{1}}{z_{2}}$为纯虚数，$\lf z_{1} \rh = \lf z_{2} \rh = 1$，$\lf z_{1} + z_{2} + z_{3} \rh = 1$，则$\lf z_{3} \rh$的最小值是\_\_\_\_\_\_\_\_.
# 答案：
# 提示：设$z = z_{1} + z_{2} + z_{3}$，则$z = 1$，由已知 $\frc{z_{1}}{z_{2}} + \ovrl{(\frc{z_{1}}{z_{2}})} = 0$ ∴$z_{1}\ovrl{z_{2}} + z_{2}\ovrl{z_{1}} = 0$
# ∴$\lf z_{1} + z_{2} \rh^{2} = \lf( z_{1} + z_{2} \rh)\lf( \ovrl{z_{1} + z_{2}} \rh) = z_{1}\ovrl{z_{1}} + z_{2}\ovrl{z_{2}} + \ovrl{z_{1}}z_{2} + z_{1}\ovrl{z_{2}} = 2$ ∴$\lf z_{1} + z_{2} \rh = \sqr{2}$
# ∴$\lf z_{3} \rh = \lf z_{1} + z_{2} - z \rh \q \lf z_{1} + z_{2} \rh - \lf z \rh = \sqr{2} - 1$。 当 时，最小值能取到。
# 6.已知正四面体可容纳10个半径为1的小球，则正四面体棱长的最小值为\_\_\_\_\_\_\_\_.
# 答案： $4 + 2\sqr{6}$
# 提示：当正四面体棱长最小时，设棱长为$$，此时，一、二、三层分别有1、3、6个小球，
# 且相邻小球两两相切，注意到重心分四面体的高为$1 : 3$，所以正四面体的高
# $h = \sqr{\frc{2}{3}} = 3 + \sqr{\frc{2}{3}} \co 2 + \sqr{\frc{2}{3}} \co 2 + 1$, 得$ = 4 + 2\sqr{6}$
# 7\. 设是定义在上的单调函数，对任意有，，则  .
# 答案：
# 提示：由题意存在使。又因是上的单调函数，这样的是唯一的，再由得
# 解得或（舍）。所以，。
# 8.已知$\brlu \x{ABC}$为椭圆$\frc{x^{2}}{9} + \frc{y^{2}}{4} = 1$的内接三角形，且$AB$过点$P(1,0)$，则$\brlu \x{ABC}$的面积的最大值为\_\_\_\_\_\_\_\_.
# 答案： $\frc{16\sqr{2}}{3}$
# 提示：经伸缩变换$\lf\{ \b{rx}
# x = 3X \\
# y = 2Y \\
# \{rx} \rh.\ $得$\brlu A^{'}B^{'}C^{'}$内接于圆$X^{2} + Y^{2} = 1$，$A^{'}B^{'}$过点$P^{'}(\frc{1}{3},0)$，
# $S_{\brlu \x{ABC}} = 6S_{\brlu A^{'}B^{'}C^{'}}$，设$O^{'}$距$A^{'}B^{'}$的距离为$$，则$0 \lq  \lq \frc{1}{3}$，$\lf A^{'}B^{'} \rh = 2\sqr{1 - ^{2}}$，$S_{\brlu A^{'}B^{'}C^{'}} \lq \sqr{1 - ^{2}} \co (1 + )$，易知当 $ = \frc{1}{3}$ 时，$S_{\brlu A^{'}B^{'}C^{'}}$有最大值为$\frc{8\sqr{2}}{9}$，∴$S_{\brlu \x{ABC}}$的最大值为 $\frc{16\sqr{2}}{3}$.
# 二、解答题(第9题16分，第10、11题各20分)
# 9.已知过点$P(3,0)$斜率为$k$的直线$l$交双曲线$C$：$x^{2} - \frc{y^{2}}{3} = 1$右支于$A、B$两点，$F$为双曲线$C$的右焦点，且$\lf \x{AF} \rh + \lf \x{BF} \rh = 16$，求$k$的值.
# 解：设$A(x_{1},y_{1})$，$B(x_{2},y_{2})$，则直线 $l$：$y = k\lf( x - 3 \rh)$.离心率$\hbb{} = 2$。\...\...4分
# 联立 $\lf\{ \b{rx}
# y = k\lf( x - 3 \rh) \\
# x^{2} - \frc{y^{2}}{3} = 1 \\
# \{rx} \rh.\ $ 得$\lf( k^{2} - 3 \rh)x^{2} - 6k^{2}x + 9k^{2} + 3 = 0$
# ∴$x_{1} + x_{2} = \frc{6k^{2}}{k^{2} - 3}$\...\...\.....8分
# ∴$16 = \lf \x{AF} \rh + \lf \x{BF} \rh = \lf( 2x_{1} - 1 \rh) + \lf( 2x_{2} - 1 \rh) = 2 \s \frc{6k^{2}}{k^{2} - 3} - 2$ \...\....12分
# ∴$k = \ 3$. \...\..... 16分。
# 10.数列$\{ _{}\}$满足$_{1} = 3$，$_{2} = 6$，$_{ + 2} = \frc{_{ + 1}^{2} + 9}{_{}}( \ \hbf{Z}^{+})$.
# （1）证明：数列$\{ _{}\}$是正整数数列；
# （2）是否存在$ \ \hbf{Z}^{+}$，使得$2109 \ _{}$，并说明理由.
# 证明：（1）已知 $_{3} = 15$，$_{}_{ + 2} = _{ + 1}^{2} + 9$ ∴$_{ + 1}_{ + 3} = _{ + 2}^{2} + 9$
# 相减得 $\frc{_{ + 3} + _{ + 1}}{_{ + 2}} = \frc{_{ + 2} + _{}}{_{ + 1}}$
# ∴$\{\frc{_{ + 2} + _{}}{_{ + 1}}\}$为常数数列。\...\...\.... 5分
# ∴$\frc{_{ + 2} + _{}}{_{ + 1}} = \frc{_{3} + _{1}}{_{2}} = 3$
# ∴$_{ + 2} = 3_{ + 1} - _{}$，又∵$_{1},_{2} \ \hbf{Z}$ ∴$_{} \ \hbf{Z}( \ \hbf{Z}^{+})$
# 又∵$_{}  0$，∴$_{} \ \hbf{Z}^{+}( \ \hbf{Z}^{+})$ \...\.... 10分
# （2）∵$2109 = 3 \s 19 \s 37$，假设有$2109 \ _{}$，则$19 \ _{}$。\..... 15分
# 法一：由 $_{1} = 3$，$_{2} = 6$，$_{ + 2} = 3_{ + 1} - _{}$
# 得 $_{} \quv 3,6,15,1,7,1,15,6,3,3,6,\los(o\ 19)$
# ∴$19 \ _{}( \ \hbf{Z}^{+})$ ∴$19 \ _{}$
# 法二：∵$_{}_{ + 2} = _{ + 1}^{2} + 9$ ∴$_{ + 1}^{2} \quv - 9(o\ 19)$
# 由费马小定理得 $1 \quv - 1(o\ 19)$，矛盾.
# 所以不存在$ \ \hbf{Z}^{+}$，使得$2109 \ _{}$，得证. \...\...20分
# 11.已知 $x,y \q 0$，$x^{2019} + y = 1$，求证 $x + y^{2019}  1 - \frc{1}{300}$.
# 注：可直接应用以下结论
# （1）$\l x \lq x - 1(x  0)$；（2）$\l 2019 \rox 7.610$。
# 证明：设 $ = 2019$，$f\lf( x \rh) = x + y^{},x,y \q 0$，则 $f\lf( x \rh) = x + {(1 - x^{})}^{}$，$0 \lq x \lq 1$.
# 只要证 ${f\lf( x \rh)}_{\}  1 - \frc{1}{300}$，因为 $f\lf( 0 \rh) = f\lf( 1 \rh) = 1  1 - \frc{1}{300}$, 所以只要证明：对满足$f^{'}\lf( x \rh) = 0$的$x$，有 $f\lf( x \rh)  1 - \frc{1}{300}$。\..... 5分
# 令 $f^{'}\lf( x \rh) = 1 - ^{2}x^{ - 1}\lf( 1 - x^{} \rh)^{ - 1} = 0$ 得$xy = ^{- \ \frc{2}{ - 1}}$，
# 此时 $f\lf( x \rh) = x + y^{} =  \s \frc{x}{} + y^{} \q \lf(  + 1 \rh) \co \sqr{} \rh)^{}y^{}} = \lf(  + 1 \rh) \co \lf( \frc{1}{} \co ^{- \ \frc{2}{ - 1}} \rh)^{\frc{}{ + 1}}$
# $= \frc{ + 1}{} \co ^{- \ \frc{1}{ - 1}}$，\...\...\... 10分
# ∴$f\lf( x \rh)  1 - \frc{1}{300} \Lfrrow \frc{ + 1}{} \co ^{- \ \frc{1}{ - 1}}  1 - \frc{1}{300} \Lfrhrrow ^{- \ \frc{1}{ - 1}}  \lf( 1 - \frc{1}{300} \rh) \co \frc{}{ + 1}$
# $\Lfrhrrow - \l 2019  2018\lbrck\ \l{\lf( 1 - \frc{1}{300} \rh) +}\l\lf( 1 - \frc{1}{2020} \rh)\ \rbrck$ . \...\..... 15分
# ∵$\l x \lq x - 1$∴$2018\lf\lbrck \ \l{\lf( 1 - \frc{1}{300} \rh) +}\l\lf( 1 - \frc{1}{2020} \rh)\  \rh\rbrck \lq 2018\lf( - \frc{1}{300} - \frc{1}{2020} \rh) < - 7.7 < - \l 2019 \rox - 7.61$，不等式成立，得证. \...\..... 20分
