# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
import joblib
import datasets

# %% [markdown]
# # Train

# %%
import re

def remove_image_string(input_string):
    pattern = r"!\[(.*?)\]\(.*?\)\{width=\".*?\" height=\".*?\"\}|!\[.*?\]\(.*?\)|\[.*?\]\{.*?\}"
    result = re.sub(pattern, "", input_string)
    return result

def remove_noise_character(input_string):
    pattern = r"[>*|image|data|media|png]"
    
    return re.sub(pattern, "", input_string)

def one_text_pre_process(text):
    precessed_text_split_lines = []
    
    for line in text.splitlines():
        remove_image_line = remove_image_string(line)

        if remove_image_line.strip() in ["", ">"]:
            continue

        remove_image_line = remove_noise_character(remove_image_line)
        precessed_text_split_lines.append(remove_image_line)
        
    return "\n".join(precessed_text_split_lines)

def pre_process(text_list):
    precessed_text_list = [one_text_pre_process(text) for text in text_list]
    return precessed_text_list

def dataset_map_pre_process(row):
    row["text"] = one_text_pre_process(row["text"])
    return row

# %%
import jieba

def chinese_tokenizer(text):
    tokens = jieba.cut(text)
    return list(tokens)


def train(dataset):
    vectorizer = CountVectorizer(tokenizer=chinese_tokenizer, ngram_range=(1, 5))
    classifier = LogisticRegression(max_iter=1000, verbose=1)
    model = make_pipeline(vectorizer, classifier)
    
    model.fit(dataset["text"], dataset["label"])
    return model

# %%
datadict = datasets.load_dataset("ranWang/test_paper_textClassifier")
# Out:
# Downloading readme:   0%|          | 0.00/457 [00:00<?, ?B/s]
# Downloading and preparing dataset None/None to /home/ran/.cache/huggingface/datasets/ranWang___parquet/ranWang--test_paper_textClassifier-e29578b85194b497/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/29.3M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating test split:   0%|          | 0/387 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/2779 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /home/ran/.cache/huggingface/datasets/ranWang___parquet/ranWang--test_paper_textClassifier-e29578b85194b497/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
train_dataset = datadict["train"]

# %%
train_dataset = train_dataset.map(dataset_map_pre_process)
# Out:
# Map:   0%|          | 0/2779 [00:00<?, ? examples/s]

# %%
model = train(train_dataset)
# Out:
# /home/ran/.local/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =     18202725     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.92626D+03    |proj g|=  3.63434D+05
#
# At iterate   50    f=  1.80253D+02    |proj g|=  8.14122D+03
#
# At iterate  100    f=  7.95707D+01    |proj g|=  1.96024D+03
#
# At iterate  150    f=  5.68351D+01    |proj g|=  1.45860D+02
#
# At iterate  200    f=  4.50477D+01    |proj g|=  1.96235D+02
#
# At iterate  250    f=  3.89243D+01    |proj g|=  1.13622D+02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate  300    f=  2.44315D+01    |proj g|=  1.00393D+00
#
# At iterate  350    f=  2.24613D+01    |proj g|=  2.73992D+01
#
# At iterate  400    f=  2.17948D+01    |proj g|=  2.20876D+02
#
# At iterate  450    f=  2.15096D+01    |proj g|=  1.29328D+00
#
# At iterate  500    f=  2.12875D+01    |proj g|=  9.65164D-01
#
# At iterate  550    f=  2.12275D+01    |proj g|=  4.95107D+00
#
# At iterate  600    f=  2.11938D+01    |proj g|=  4.90144D+00
#
# At iterate  650    f=  2.11703D+01    |proj g|=  1.29348D+00
#
# At iterate  700    f=  2.11575D+01    |proj g|=  2.00737D+00
#
# At iterate  750    f=  2.11522D+01    |proj g|=  1.97003D+00
#
# At iterate  800    f=  2.11458D+01    |proj g|=  8.89306D+00
#
# At iterate  850    f=  2.11446D+01    |proj g|=  2.88593D+00
#
# At iterate  900    f=  2.11432D+01    |proj g|=  1.78054D+00
#
# At iterate  950    f=  2.11416D+01    |proj g|=  5.33317D-01
#
# At iterate 1000    f=  2.11410D+01    |proj g|=  1.99100D-01
#
# At iterate 1050    f=  2.11405D+01    |proj g|=  1.24651D+00
#
# At iterate 1100    f=  2.11403D+01    |proj g|=  4.02218D-01
#
# At iterate 1150    f=  2.11401D+01    |proj g|=  2.54527D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# *****   1171   2073      2     0     0   6.061D-02   2.114D+01
#   F =   21.140056600681518
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 48.2min finished

# %%
joblib.dump(model, 'TextClassifie-13m.pkl')
# Out:
# ['TextClassifier-new-63m.pkl']

# %% [markdown]
# # 模型数据

# %%
print("模型方程: y = ", model.named_steps['logisticregression'].coef_, " * x + ", model.named_steps['logisticregression'].intercept_)

print("参数量: ", model.named_steps['logisticregression'].coef_.size + 1)
# Out:
# 模型方程: y =  [[ 5.69997076e-02 -9.37742454e-04  5.54575040e-07 ...  2.01404136e-08
#    2.01404136e-08  2.01404136e-08]]  * x +  [-2.05576517]
# 参数量:  18202725

# %%
count_vectorizer = model.steps[0][1]

# %%
count_vectorizer.vocabulary_
# Out:
# {'北师大': 7627371,
#  '版': 12690599,
#  '小学': 9555423,
#  '三年级': 4978322,
#  '下册': 5086834,
#  '数学': 11240116,
#  '第六': 14016926,
#  '单元': 7700473,
#  '《': 4662663,
#  '认识': 15048884,
#  '分数': 7271788,
#  '》': 4673438,
#  '单元测试': 7701102,
#  '3': 2039044,
#  '（': 16384374,
#  '附': 16028151,
#  '答案': 14079262,
#  '）': 16483839,
#  '\n': 0,
#  '一': 4749334,
#  '、': 4124608,
#  '用': 12844651,
#  '表示': 14799757,
#  '下面': 5103166,
#  '每个': 12230159,
#  '图里': 8608515,
#  '的': 12987750,
#  '阴影': 16019957,
#  '部分': 15770992,
#  '。': 4433296,
#  '每空': 12250018,
#  '2': 1839560,
#  '分': 7221997,
#  '，': 16683449,
#  '共': 6933667,
#  '12': 1751932,
#  '二': 5957558,
#  '判断题': 7413674,
#  '对': 9428348,
#  '在': 8631910,
#  '括号': 10894029,
#  '里': 15827869,
#  '打': 10731060,
#  '"': 887094,
#  '√': 3892070,
#  '错': 15914918,
#  '×': 3789532,
#  '10': 1709087,
#  '1': 1602748,
#  ' ': 383869,
#  '是': 11535280,
#  '同': 8174450,
#  '分母': 7293829,
#  '相加': 13671825,
#  '减': 7134218,
#  '不变': 5157120,
#  '分子': 7261146,
#  '＋': 16663564,
#  '=': 2452804,
#  '4': 2146946,
#  '如': 9120412,
#  '左图': 9761460,
#  '长方形': 15946921,
#  '与': 5246497,
#  '正方形': 12176516,
#  '一样': 4879818,
#  '大': 8986550,
#  '5': 2227795,
#  '有': 11763085,
#  '个球': 5458370,
#  '拿出': 10899743,
#  '应该': 10002152,
#  '拿': 10898207,
#  '个': 5419739,
#  '三': 4956822,
#  '填空题': 8893614,
#  '第': 13986815,
#  '题': 16215642,
#  '16': 1803881,
#  '24': 1994648,
#  '52': 2272739,
#  '个数': 5453469,
#  '点': 12615313,
#  '全部': 6870609,
#  '占': 7714266,
#  '来源': 11971329,
#  '：': 17916433,
#  'www': 3571577,
#  '.': 1424408,
#  'bcjy123': 2927360,
#  'co': 3034422,
#  '/': 1537045,
#  'ku': 3238741,
#  '○': 4076951,
#  '填上': 8890874,
#  '﹥': 16374486,
#  '﹤': 16374131,
#  '或': 10612963,
#  '直接': 13621501,
#  '写出': 7089309,
#  '得数': 10292781,
#  '－': 17780864,
#  '四': 8482535,
#  '解决问题': 14978108,
#  '8': 2365827,
#  '其余': 7021253,
#  '每题': 12252155,
#  '9': 2402746,
#  '26': 2009886,
#  '一块': 4835047,
#  '月饼': 11763043,
#  '小明': 9568560,
#  '吃': 8125324,
#  '了': 5847524,
#  '小': 9539890,
#  '李': 11929243,
#  '他们': 6230356,
#  '一共': 4817864,
#  '这个': 15541699,
#  '饼': 16256925,
#  '几分': 7155713,
#  '之': 5740944,
#  '几': 7147116,
#  '？': 18180669,
#  '还': 15502474,
#  '剩下': 7508696,
#  '画出': 12951999,
#  '如下': 9124924,
#  '图形': 8591525,
#  '两种': 5395283,
#  '不同': 5161821,
#  '法': 12428325,
#  '红': 14193512,
#  '金鱼': 15883529,
#  '条': 11945754,
#  '黄金': 16326605,
#  '鱼': 16316047,
#  '黑': 16327417,
#  '请': 15192532,
#  '你': 6500265,
#  '提出': 11032056,
#  '有关': 11818141,
#  '问题': 15965892,
#  '并': 9950429,
#  '解决': 14970874,
#  '卷': 7763014,
#  '0': 1545243,
#  '北师大 版': 7627396,
#  '版 小学': 12690780,
#  '小学 三年级': 9555585,
#  '三年级 下册': 4978376,
#  '下册 数学': 5086877,
#  '数学 第六': 11245038,
#  '第六 单元': 14016946,
#  '单元 《': 7700569,
#  '《 认识': 4672143,
#  '认识 分数': 15050077,
#  '分数 》': 7272068,
#  '》 单元测试': 4677254,
#  '单元测试 3': 7701115,
#  '3 （': 2078267,
#  '（ 附': 16476809,
#  '附 答案': 16028237,
#  '答案 ）': 14086465,
#  '） \n': 16483840,
#  '\n 一': 194315,
#  '一 、': 4751123,
#  '、 用': 4354466,
#  '用 分数': 12852087,
#  '分数 表示': 7274047,
#  '表示 下面': 14801482,
#  '下面 每个': 5105324,
#  '每个 图里': 12231513,
#  '图里 的': 8608531,
#  '的 阴影': 13548490,
#  '阴影 部分': 16020205,
#  '部分 。': 15771491,
#  '。 （': 4659417,
#  '（ 每空': 16468602,
#  '每空 2': 12250060,
#  '2 分': 1896851,
#  '分 ，': 7241797,
#  '， 共': 16993382,
#  '共 12': 6934100,
#  '12 分': 1757148,
#  '分 ）': 7231239,
#  '\n 二': 210039,
#  '二 、': 5958713,
#  '、 判断题': 4219850,
#  '判断题 。': 7413712,
#  '（ 对': 16461957,
#  '对 的': 9455593,
#  '的 在': 13180716,
#  '在 括号': 8692512,
#  '括号 里': 10894445,
#  '里 打': 15830265,
#  '打 "': 10731061,
#  '" √': 912286,
#  '√ "': 3892359,
#  '" ，': 1120370,
#  '， 错': 17740342,
#  '错 的': 15915354,
#  '的 打': 13288166,
#  '" ×': 912006,
#  '× "': 3790441,
#  '" 。': 916213,
#  '。 ）': 4660995,
#  '） （': 16639848,
#  '共 10': 6933792,
#  '10 分': 1717113,
#  '\n 1': 50126,
#  '1 、': 1639697,
#  '、  ': 4125464,
#  '  是': 816456,
#  '是 表示': 11643404,
#  '表示 阴影': 14809188,
#  '部分 的': 15775104,
#  '的 分数': 13117765,
#  '分数 。': 7272004,
#  '。  ': 4477672,
#  '  （': 864587,
#  '（  ': 16384412,
#  '  ）': 869818,
#  '\n 2': 66444,
#  '2 、': 1888225,
#  '、 同': 4237260,
#  '同 分母': 8175791,
#  '分母 分数': 7294254,
#  '分数 相加': 7273966,
#  '相加 减': 13671921,
#  '减 ，': 7135323,
#  '， 分母': 17026354,
#  '分母 不变': 7293977,
#  '不变 ，': 5158369,
#  '， 分子': 17025220,
#  '分子 相加': 7262751,
#  '减 。': 7134469,
#  '\n 3': 78479,
#  '3 、': 2061125,
#  '、 ＋': 4431747,
#  '＋  ': 16663673,
#  '  =': 525212,
#  '=  ': 2456517,
#  '\n 4': 85670,
#  '4 、': 2163311,
#  '  如': 790664,
#  '如 左图': 9122416,
#  '左图 长方形': 9761540,
#  '长方形 的': 15947885,
#  '的 与': 13030255,
#  '与 正方形': 5285213,
#  '正方形 的': 12178662,
#  '的 一样': 13019010,
#  '一样 大': 4880705,
#  '大 。': 8987623,
#  '\n 5': 90954,
#  '5 、': 2238832,
#  '、 有': 4325365,
#  '有 12': 11766664,
#  '12 个球': 1756767,
#  '个球 ，': 5458637,
#  '， 拿出': 17370018,
#  '拿出 ，': 10900742,
#  '， 应该': 17274731,
#  '应该 拿': 10003532,
#  '拿 3': 10898244,
#  '3 个': 2064342,
#  '个 。': 5422950,
#  '\n 三': 199547,
#  '三 、': 4957735,
#  '、 填空题': 4250918,
#  '填空题 。': 8893889,
#  '（ 第': 16471875,
#  '第 1': 13987054,
#  '1 题': 1660332,
#  '题 12': 16216550,
#  '， 第': 17576628,
#  '第 2': 13988268,
#  '2 题': 1907816,
#  '题 16': 16216577,
#  '16 分': 1807120,
#  '第 3': 13989210,
#  '3 题': 2077538,
#  '题 24': 16216648,
#  '24 分': 1996953,
#  '共 52': 6935844,
#  '52 分': 2273263,
#  '、 \n': 4124609,
#  '\n （': 368580,
#  '（ 1': 16389472,
#  '1 ）': 1662667,
#  '）  ': 16498065,
#  '  的': 832956,
#  '的 个数': 13037594,
#  '个数 点': 5455956,
#  '点 全部': 12626501,
#  '全部 的': 6872297,
#  '的 。': 13008564,
#  '。 \n': 4433297,
#  '（ 2': 16402701,
#  '2 ）': 1910014,
#  '   ': 387953,
#  '个数 占': 5454868,
#  '占 全部': 7715062,
#  '。 来源': 4605737,
#  '来源 ：': 11971713,
#  '： www': 17962079,
#  'www .': 3571582,
#  '. bcjy123': 1474022,
#  'bcjy123 .': 2927361,
#  '. co': 1474555,
#  'co /': 3036347,
#  '/ ku': 1542186,
#  'ku /': 3238753,
#  '/ \n': 1537046,
#  '（ 3': 16414334,
#  '3 ）': 2078667,
#  '） 与': 16539784,
#  '与  ': 5246582,
#  '、 在': 4245364,
#  '在 ○': 8641825,
#  '○ 里': 4078957,
#  '里 填上': 15829736,
#  '填上 "': 8890879,
#  '" ﹥': 1119564,
#  '﹥ "': 16374550,
#  '" "': 895564,
#  '" ﹤': 1119554,
#  '﹤ "': 16374248,
#  '" 或': 1023355,
#  '或 "': 10613788,
#  '" =': 904853,
#  '= "': 2462416,
#  '1 \n': 1602749,
#  '、 直接': 4359490,
#  '直接 写出': 13622004,
#  '写出 得数': 7091307,
#  '得数 。': 10292847,
#  '\n ＋': 377726,
#  '  －': 878916,
#  '－  ': 17781070,
#  '  ＋': 874707,
#  '= \n': 2452805,
#  '\n －': 381027,
#  '  1': 472892,
#  '1 －': 1692944,
#  '\n 四': 254230,
#  '四 、': 8483086,
#  '、 解决问题': 4397206,
#  '解决问题 。': 14978305,
#  '题 8': 16216775,
#  '8 分': 2375315,
#  '， 其余': 17005378,
#  '其余 每题': 7021757,
#  '每题 9': 12252344,
#  '9 分': 2409854,
#  '共 26': 6934944,
#  '26 分': 2011027,
#  '、 一块': 4164036,
#  '一块 月饼': 4835574,
#  '月饼 ，': 11763076,
#  '， 小明': 17237845,
#  '小明 吃': 9569206,
#  '吃 了': 8125956,
#  '了 ，': 5921770,
#  '， 小': 17236228,
#  '小 李': 9542587,
#  '李 吃': 11929373,
#  '了 。': 5856492,
#  '） 他们': 16546508,
#  '他们 一共': 6230510,
#  '一共 吃': 4818291,
#  '了 这个': 5916805,
#  '这个 饼': 15552961,
#  '饼 的': 16256971,
#  '的 几分': 13114484,
#  '几分 之': 7155725,
#  '之 几': 5742804,
#  '几 ？': 7147743,
#  '？ \n': 18180670,
#  '） 还': 16633821,
#  '还 剩下': 15505885,
#  '剩下 几分': 7509300,
#  '用 阴影': 12865936,
#  '阴影 画出': 16020154,
#  '画出 如下': 12952979,
#  '如下 图形': 9125675,
#  '图形 的': 8594722,
#  '的 ，': 13573897,
#  '， 画出': 17542921,
#  '画出 两种': 12952326,
#  '两种 不同': 5395319,
#  '不同 分': 5162439,
#  '分 法': 7230079,
#  '法 。': 12429618,
#  '、 红': 4375411,
#  '红 金鱼': 14194174,
#  '金鱼 3': 15883534,
#  '3 条': 2074122,
#  '条 ，': 11947491,
#  '， 黄金': 17762503,
#  '黄金 鱼': 16326810,
#  '鱼 4': 16316073,
#  '4 条': 2173875,
#  '其余 的': 7021796,
#  '的 是': 13331686,
#  '是 黑': 11654578,
#  '黑 金鱼': 16328092,
#  '金鱼 。': 15883542,
#  '\n 请': 357477,
#  '请 你': 15193050,
#  '你 提出': 6508798,
#  '提出 有关': 11034343,
#  '有关 分数': 11819006,
#  '分数 的': 7273523,
#  '的 数学': 13307926,
#  '数学 问题': 11245708,
#  '问题 并': 15977003,
#  '并 解决': 9961091,
#  '解决 。': 14971291,
#  '  ？': 885200,
#  '\n 第六': 333309,
#  '第六 单元测试': 14016966,
#  '单元测试 卷': 7701131,
#  '卷 的': 7764271,
#  '的 部分': 13528505,
#  '部分 答案': 15775996,
#  '答案 ：': 14086790,
#  '： \n': 17916434,
#  '、 ×': 4159455,
#  '×  ': 3789928,
#  '  √': 732185,
#  '√  ': 3892184,
#  '  ×': 729051,
#  '√ \n': 3892071,
#  '、 1': 4133523,
#  '、 （': 4430610,
#  '、 ﹥': 4430591,
#  '﹥  ': 16374504,
#  '  ﹥': 864480,
#  '  ﹤': 864411,
#  '﹤  ': 16374168,
#  '﹥ \n': 16374487,
#  '1  ': 1604298,
#  '  0': 468574,
#  '0 \n': 1545244,
#  '北师大 版 小学': 7627462,
#  '版 小学 三年级': 12690784,
#  '小学 三年级 下册': 9555590,
#  '三年级 下册 数学': 4978377,
#  '下册 数学 第六': 5086908,
#  '数学 第六 单元': 11245039,
#  '第六 单元 《': 14016947,
#  '单元 《 认识': 7700627,
#  '《 认识 分数': 4672147,
#  '认识 分数 》': 15050085,
#  '分数 》 单元测试': 7272069,
#  '》 单元测试 3': 4677263,
#  '单元测试 3 （': 7701116,
#  '3 （ 附': 2078632,
#  '（ 附 答案': 16476813,
#  '附 答案 ）': 16028264,
#  '答案 ） \n': 14086466,
#  '） \n 一': 16492120,
#  '\n 一 、': 194384,
#  '一 、 用': 4753326,
#  '、 用 分数': 4354653,
#  '用 分数 表示': 12852109,
#  '分数 表示 下面': 7274062,
#  '表示 下面 每个': 14801495,
#  '下面 每个 图里': 5105330,
#  '每个 图里 的': 12231514,
#  '图里 的 阴影': 8608535,
#  '的 阴影 部分': 13548512,
#  '阴影 部分 。': 16020253,
#  '部分 。 （': 15771627,
#  '。 （ 每空': 4660505,
#  '（ 每空 2': 16468610,
#  '每空 2 分': 12250061,
#  '2 分 ，': 1898120,
#  '分 ， 共': 7242296,
#  '， 共 12': 16993470,
#  '共 12 分': 6934117,
#  '12 分 ）': 1757444,
#  '分 ） \n': 7231240,
#  '） \n 二': 16492688,
#  '\n 二 、': 210106,
#  '二 、 判断题': 5959688,
#  '、 判断题 。': 4219868,
#  '判断题 。 （': 7413738,
#  '。 （ 对': 4660237,
#  '（ 对 的': 16461970,
#  '对 的 在': 9455748,
#  '的 在 括号': 13180816,
#  '在 括号 里': 8692551,
#  '括号 里 打': 10894549,
#  '里 打 "': 15830266,
#  '打 " √': 10731094,
#  '" √ "': 912293,
#  '√ " ，': 3892464,
#  '" ， 错': 1140744,
#  '， 错 的': 17740348,
#  '错 的 打': 15915380,
#  '的 打 "': 13288167,
#  '打 " ×': 10731082,
#  '" × "': 912007,
#  '× " 。': 3790473,
#  '" 。 ）': 924579,
#  '。 ） （': 4661226,
#  '） （ 每空': 16641891,
#  '， 共 10': 16993417,
#  '共 10 分': 6933835,
#  '10 分 ）': 1717488,
#  '） \n 1': 16485556,
#  '\n 1 、': 51404,
#  '1 、  ': 1639742,
#  '、   是': 4128141,
#  '  是 表示': 817062,
#  '是 表示 阴影': 11643432,
#  '表示 阴影 部分': 14809189,
#  '阴影 部分 的': 16020480,
#  '部分 的 分数': 15775238,
#  '的 分数 。': 13117790,
#  '分数 。  ': 7272042,
#  '。   （': 4480359,
#  '  （  ': 864597,
#  '（   ）': 16385523,
#  '  ） \n': 869819,
#  '） \n 2': 16486980,
#  '\n 2 、': 67801,
#  '2 、 同': 1890061,
#  '、 同 分母': 4237298,
#  '同 分母 分数': 8175805,
#  '分母 分数 相加': 7294306,
#  '分数 相加 减': 7273970,
#  '相加 减 ，': 13671942,
#  '减 ， 分母': 7135362,
#  '， 分母 不变': 17026382,
#  '分母 不变 ，': 7293981,
#  '不变 ， 分子': 5158587,
#  '， 分子 相加': 17025376,
#  '分子 相加 减': 7262755,
#  '相加 减 。': 13671925,
#  '减 。  ': 7134477,
#  '） \n 3': 16487737,
#  '\n 3 、': 79626,
#  '3 、 ＋': 2063752,
#  '、 ＋  ': 4431748,
#  '＋   =': 16663769,
#  '  =  ': 525460,
#  '=   （': 2462178,
#  '） \n 4': 16488185,
#  '\n 4 、': 86661,
#  '4 、  ': 2163343,
#  '、   如': 4127298,
#  '  如 左图': 790715,
#  '如 左图 长方形': 9122417,
#  '左图 长方形 的': 9761541,
#  '长方形 的 与': 15947901,
#  '的 与 正方形': 13030334,
#  '与 正方形 的': 5285257,
#  '正方形 的 一样': 12178691,
#  '的 一样 大': 13019032,
#  '一样 大 。': 4880741,
#  '大 。  ': 8987742,
#  '） \n 5': 16488488,
#  '\n 5 、': 91768,
#  '5 、 有': 2239974,
#  '、 有 12': 4325392,
#  '有 12 个球': 11766730,
#  '12 个球 ，': 1756774,
#  '个球 ， 拿出': 5458776,
#  '， 拿出 ，': 17370257,
#  '拿出 ， 应该': 10900743,
#  '， 应该 拿': 17274856,
#  '应该 拿 3': 10003533,
#  '拿 3 个': 10898245,
#  '3 个 。': 2064538,
#  '个 。  ': 5423169,
#  '） \n 三': 16492319,
#  '\n 三 、': 199603,
#  '三 、 填空题': 4958942,
#  '、 填空题 。': 4251019,
#  '填空题 。 （': 8893936,
#  '。 （ 第': 4660644,
#  '（ 第 1': 16471879,
#  '第 1 题': 13987463,
#  '1 题 12': 1660344,
#  '题 12 分': 16216551,
#  '12 分 ，': 1757997,
#  '分 ， 第': 7243347,
#  '， 第 2': 17576842,
#  '第 2 题': 13988621,
#  '2 题 16': 1907833,
#  '题 16 分': 16216578,
#  '16 分 ，': 1807360,
#  '， 第 3': 17577014,
#  '第 3 题': 13989550,
#  '3 题 24': 2077549,
#  '题 24 分': 16216649,
#  '24 分 ，': 1997058,
#  '， 共 52': 16993896,
#  '共 52 分': 6935845,
#  '52 分 ）': 2273269,
#  '1 、 \n': 1639698,
#  '、 \n （': 4125431,
#  '\n （ 1': 368733,
#  '（ 1 ）': 16390622,
#  '1 ）  ': 1663006,
#  '）   的': 16501224,
#  '  的 个数': 833070,
#  '的 个数 点': 13038443,
#  '个数 点 全部': 5455957,
#  '点 全部 的': 12626502,
#  '全部 的 。': 6872326,
#  '的 。 \n': 13008565,
#  '。 \n （': 4477276,
#  '\n （ 2': 370001,
#  '（ 2 ）': 16403543,
#  '2 ）  ': 1910365,
#  '）    ': 16498125,
#  '    的': 442873,
#  '的 个数 占': 13038059,
#  '个数 占 全部': 5454869,
#  '占 全部 的': 7715084,
#  '的 。 来源': 13011310,
#  '。 来源 ：': 4605738,
#  '来源 ： www': 11971723,
#  '： www .': 17962083,
#  'www . bcjy123': 3571583,
#  '. bcjy123 .': 1474023,
#  'bcjy123 . co': 2927362,
#  '. co /': 1474675,
#  'co / ku': 3036419,
#  '/ ku /': 1542187,
#  'ku / \n': 3238754,
#  '/ \n （': 1537815,
#  '\n （ 3': 371526,
#  '（ 3 ）': 16414893,
#  '3 ） 与': 2081117,
#  '） 与  ': 16539788,
#  '与    ': 5246583,
#  '。 \n 2': 4439929,
#  '2 、 在': 1890143,
#  '、 在 ○': 4245472,
#  '在 ○ 里': 8641844,
#  '○ 里 填上': 4078968,
#  '里 填上 "': 15829740,
#  '填上 " ﹥': 8890913,
#  '" ﹥ "': 1119565,
#  '﹥ " "': 16374551,
#  '" " ﹤': 901461,
#  '" ﹤ "': 1119555,
#  '﹤ " 或': 16374258,
#  '" 或 "': 1023359,
#  '或 " =': 10613828,
#  '" = "': 904857,
#  '= " 。': 2462466,
#  '" 。 \n': 916214,
#  '。 \n 1': 4437917,
#  '\n 1 \n': 50127,
#  '1 \n 3': 1603201,
#  '3 、 直接': 2063337,
#  '、 直接 写出': 4359506,
#  '直接 写出 得数': 13622176,
#  '写出 得数 。': 7091317,
#  '得数 。 \n': 10292848,
#  '。 \n ＋': 4477538,
#  '\n ＋  ': 377727,
#  '=   －': 2462367,
#  '  －  ': 878928,
#  '－   =': 17781162,
#  '=   ＋': 2462263,
#  '  ＋  ': 874717,
#  '  = \n': 525213,
#  '= \n ＋': 2456474,
#  '= \n －': 2456486,
#  '\n －  ': 381028,
#  '=   1': 2457344,
#  '  1 －': 474827,
#  '1 －  ': 1692961,
#  '= \n 四': 2455469,
#  '\n 四 、': 254262,
#  '四 、 解决问题': 8485029,
#  '、 解决问题 。': 4397246,
#  '解决问题 。 （': 14978587,
#  '1 题 8': 1660373,
#  '题 8 分': 16216779,
#  '8 分 ，': 2375949,
#  '分 ， 其余': 7242523,
#  '， 其余 每题': 17005618,
#  '其余 每题 9': 7021777,
#  '每题 9 分': 12252345,
#  '9 分 ，': 2410176,
#  '， 共 26': 16993670,
#  '共 26 分': 6934945,
#  '26 分 ）': 2011051,
#  '1 、 一块': 1640844,
#  '、 一块 月饼': 4164055,
#  '一块 月饼 ，': 4835578,
#  '月饼 ， 小明': 11763077,
#  '， 小明 吃': 17237982,
#  '小明 吃 了': 9569207,
#  '吃 了 ，': 8126327,
#  '了 ， 小': 5924074,
#  '， 小 李': 17236343,
#  '小 李 吃': 9542599,
#  '李 吃 了': 11929374,
#  '吃 了 。': 8126038,
#  '了 。 来源': 5858779,
#  '1 ） 他们': 1668195,
#  '） 他们 一共': 16546509,
#  '他们 一共 吃': 6230514,
#  '一共 吃 了': 4818292,
#  '吃 了 这个': 8126283,
#  '了 这个 饼': 5916981,
#  '这个 饼 的': 15552962,
#  '饼 的 几分': 16256972,
#  '的 几分 之': 13114485,
#  '几分 之 几': 7155726,
#  '之 几 ？': 5742970,
#  '几 ？ \n': 7147744,
#  '？ \n （': 18184232,
#  '2 ） 还': 1927234,
#  '） 还 剩下': 16633834,
#  '还 剩下 几分': 15506080,
#  '剩下 几分 之': 7509301,
#  '？ \n 2': 18181262,
#  '2 、 用': 1890966,
#  '、 用 阴影': 4355064,
#  '用 阴影 画出': 12865940,
#  '阴影 画出 如下': 16020155,
#  '画出 如下 图形': 12952980,
#  '如下 图形 的': 9125676,
#  '图形 的 ，': 8595829,
#  '的 ， 画出': 13580018,
#  '， 画出 两种': 17542974,
#  '画出 两种 不同': 12952327,
#  '两种 不同 分': 5395320,
#  '不同 分 法': 5162443,
#  '分 法 。': 7230083,
#  '法 。 \n': 12429619,
#  '。 \n 3': 4441423,
#  '3 、 红': 2063410,
#  '、 红 金鱼': 4375441,
#  '红 金鱼 3': 14194175,
#  '金鱼 3 条': 15883535,
#  '3 条 ，': 2074182,
#  '条 ， 黄金': 11947918,
#  '， 黄金 鱼': 17762507,
#  '黄金 鱼 4': 16326811,
#  '鱼 4 条': 16316074,
#  '4 条 ，': 2173945,
#  '条 ， 其余': 11947592,
#  '， 其余 的': 17005638,
#  '其余 的 是': 7021842,
#  '的 是 黑': 13335711,
#  '是 黑 金鱼': 11654601,
#  '黑 金鱼 。': 16328093,
#  '金鱼 。 \n': 15883543,
#  '。 \n 请': 4474861,
#  '\n 请 你': 357495,
#  '请 你 提出': 15193519,
#  '你 提出 有关': 6508810,
#  '提出 有关 分数': 11034344,
#  '有关 分数 的': 11819010,
#  '分数 的 数学': 7273870,
#  '的 数学 问题': 13308550,
#  '数学 问题 并': 11245768,
#  '问题 并 解决': 15977018,
#  '并 解决 。': 9961092,
#  '解决 。 \n': 14971292,
#  '    ？': 448198,
#  '  ？ \n': 885201,
#  '3 ）  ': 2078848,
#  '？ \n 第六': 18183909,
#  '\n 第六 单元测试': 333318,
#  '第六 单元测试 卷': 14016967,
#  '单元测试 卷 的': 7701143,
#  '卷 的 部分': 7764297,
#  '的 部分 答案': 13528923,
#  '部分 答案 ：': 15775997,
#  '答案 ： \n': 14086791,
#  '： \n 一': 17921378,
#  '一 、 \n': 4751124,
#  '、 \n 二': 4125147,
#  '二 、 ×': 5959019,
#  '、 ×  ': 4159477,
#  '×   √': 3790353,
#  '  √  ': 732211,
#  '√   ×': 3892302,
#  '  ×  ': 729085,
#  '×   ×': 3790318,
#  '  √ \n': 732186,
#  '√ \n 三': 3892113,
#  '三 、 1': 4957836,
#  '、 1 、': 4133800,
#  '1 、 （': 1642898,
#  '、 （ 1': 4430725,
#  '）   （': 16501551,
#  '  （ 2': 865636,
#  '  （ 3': 866397,
#  '3 ） \n': 2078668,
#  '2 、 ﹥': 1891568,
#  '、 ﹥  ': 4430592,
#  '﹥   ﹥': 16374537,
#  '  ﹥  ': 864492,
#  '﹥   =': 16374517,
#  '=   =': 2460971,
#  '=   ﹥': 2462168,
#  '﹥   ﹤': 16374527,
#  '  ﹤  ': 864434,
#  '﹤   ﹥': 16374239,
#  '  ﹥ \n': 864481,
#  '﹥ \n 3': 16374491,
#  '3 、  ': 2061154,
#  '、   1': 4125603,
#  '  1  ': 473009,
#  '1   0': 1604514,
#  '  0 \n': 468575,
#  '0 \n 四': 1545891,
#  '四 、 1': 8483165,
#  '北师大 版 小学 三年级': 7627465,
#  '版 小学 三年级 下册': 12690787,
#  '小学 三年级 下册 数学': 9555591,
#  '三年级 下册 数学 第六': 4978382,
#  '下册 数学 第六 单元': 5086909,
#  '数学 第六 单元 《': 11245040,
#  '第六 单元 《 认识': 14016950,
#  '单元 《 认识 分数': 7700630,
#  '《 认识 分数 》': 4672152,
#  '认识 分数 》 单元测试': 15050086,
#  '分数 》 单元测试 3': 7272074,
#  '》 单元测试 3 （': 4677264,
#  '单元测试 3 （ 附': 7701119,
#  '3 （ 附 答案': 2078633,
#  '（ 附 答案 ）': 16476814,
#  '附 答案 ） \n': 16028265,
#  '答案 ） \n 一': 14086494,
#  '） \n 一 、': 16492130,
#  '\n 一 、 用': 195409,
#  '一 、 用 分数': 4753332,
#  '、 用 分数 表示': 4354654,
#  '用 分数 表示 下面': 12852118,
#  '分数 表示 下面 每个': 7274066,
#  '表示 下面 每个 图里': 14801496,
#  '下面 每个 图里 的': 5105331,
#  '每个 图里 的 阴影': 12231517,
#  '图里 的 阴影 部分': 8608536,
#  '的 阴影 部分 。': 13548519,
#  '阴影 部分 。 （': 16020261,
#  '部分 。 （ 每空': 15771638,
#  '。 （ 每空 2': 4660508,
#  '（ 每空 2 分': 16468611,
#  '每空 2 分 ，': 12250072,
#  '2 分 ， 共': 1898149,
#  '分 ， 共 12': 7242315,
#  '， 共 12 分': 16993471,
#  '共 12 分 ）': 6934131,
#  '12 分 ） \n': 1757445,
#  '分 ） \n 二': 7232042,
#  '） \n 二 、': 16492696,
#  '\n 二 、 判断题': 210521,
#  '二 、 判断题 。': 5959698,
#  '、 判断题 。 （': 4219877,
#  '判断题 。 （ 对': 7413741,
#  '。 （ 对 的': 4660238,
#  '（ 对 的 在': 16461971,
#  '对 的 在 括号': 9455749,
#  '的 在 括号 里': 13180823,
#  '在 括号 里 打': 8692581,
#  '括号 里 打 "': 10894550,
#  '里 打 " √': 15830275,
#  '打 " √ "': 10731097,
#  '" √ " ，': 912343,
#  '√ " ， 错': 3892506,
#  '" ， 错 的': 1140745,
#  '， 错 的 打': 17740355,
#  '错 的 打 "': 15915381,
#  '的 打 " ×': 13288174,
#  '打 " × "': 10731083,
#  '" × " 。': 912021,
#  '× " 。 ）': 3790505,
#  '" 。 ） （': 924584,
#  '。 ） （ 每空': 4661241,
#  '） （ 每空 2': 16641892,
#  '分 ， 共 10': 7242307,
#  '， 共 10 分': 16993422,
#  '共 10 分 ）': 6933849,
#  '10 分 ） \n': 1717489,
#  '分 ） \n 1': 7231397,
#  '） \n 1 、': 16485667,
#  '\n 1 、  ': 51422,
#  '1 、   是': 1639810,
#  '、   是 表示': 4128154,
#  '  是 表示 阴影': 817065,
#  '是 表示 阴影 部分': 11643433,
#  '表示 阴影 部分 的': 14809190,
#  '阴影 部分 的 分数': 16020489,
#  '部分 的 分数 。': 15775239,
#  '的 分数 。  ': 13117797,
#  '分数 。   （': 7272043,
#  '。   （  ': 4480360,
#  '  （   ）': 864837,
#  '（   ） \n': 16385524,
#  '  ） \n 2': 869957,
#  '） \n 2 、': 16487040,
#  '\n 2 、 同': 68490,
#  '2 、 同 分母': 1890062,
#  '、 同 分母 分数': 4237299,
#  '同 分母 分数 相加': 8175828,
#  '分母 分数 相加 减': 7294309,
#  '分数 相加 减 ，': 7273971,
#  '相加 减 ， 分母': 13671949,
#  '减 ， 分母 不变': 7135365,
#  '， 分母 不变 ，': 17026385,
#  '分母 不变 ， 分子': 7293982,
#  '不变 ， 分子 相加': 5158595,
#  '， 分子 相加 减': 17025377,
#  '分子 相加 减 。': 7262756,
#  '相加 减 。  ': 13671926,
#  '减 。   （': 7134478,
#  '  ） \n 3': 869995,
#  '） \n 3 、': 16487806,
#  '\n 3 、 ＋': 80698,
#  '3 、 ＋  ': 2063753,
#  '、 ＋   =': 4431749,
#  '＋   =  ': 16663773,
#  '  =   （': 526931,
#  '=   （  ': 2462179,
#  '  ） \n 4': 870006,
#  '） \n 4 、': 16488221,
#  '\n 4 、  ': 86675,
#  '4 、   如': 2163370,
#  '、   如 左图': 4127299,
#  '  如 左图 长方形': 790716,
#  '如 左图 长方形 的': 9122418,
#  '左图 长方形 的 与': 9761542,
#  '长方形 的 与 正方形': 15947902,
#  '的 与 正方形 的': 13030335,
#  '与 正方形 的 一样': 5285258,
#  '正方形 的 一样 大': 12178692,
#  '的 一样 大 。': 13019033,
#  '一样 大 。  ': 4880748,
#  '大 。   （': 8987752,
#  '  ） \n 5': 870023,
#  '） \n 5 、': 16488527,
#  '\n 5 、 有': 92210,
#  '5 、 有 12': 2239975,
#  '、 有 12 个球': 4325393,
#  '有 12 个球 ，': 11766733,
#  '12 个球 ， 拿出': 1756777,
#  '个球 ， 拿出 ，': 5458777,
#  '， 拿出 ， 应该': 17370258,
#  '拿出 ， 应该 拿': 10900744,
#  '， 应该 拿 3': 17274857,
#  '应该 拿 3 个': 10003534,
#  '拿 3 个 。': 10898246,
#  '3 个 。  ': 2064545,
#  '个 。   （': 5423185,
#  '  ） \n 三': 870254,
#  '） \n 三 、': 16492324,
#  '\n 三 、 填空题': 200167,
#  '三 、 填空题 。': 4958949,
#  '、 填空题 。 （': 4251040,
#  '填空题 。 （ 第': 8893961,
#  '。 （ 第 1': 4660645,
#  '（ 第 1 题': 16471890,
#  '第 1 题 12': 13987468,
#  '1 题 12 分': 1660345,
#  '题 12 分 ，': 16216552,
#  '12 分 ， 第': 1758025,
#  '分 ， 第 2': 7243389,
#  '， 第 2 题': 17576900,
#  '第 2 题 16': 13988628,
#  '2 题 16 分': 1907834,
#  '题 16 分 ，': 16216579,
#  '16 分 ， 第': 1807374,
#  '分 ， 第 3': 7243432,
#  '， 第 3 题': 17577059,
#  '第 3 题 24': 13989556,
#  '3 题 24 分': 2077550,
#  '题 24 分 ，': 16216650,
#  '24 分 ， 共': 1997061,
#  '分 ， 共 52': 7242408,
#  '， 共 52 分': 16993897,
#  '共 52 分 ）': 6935849,
#  '52 分 ） \n': 2273270,
#  '\n 1 、 \n': 51405,
#  '1 、 \n （': 1639739,
#  '、 \n （ 1': 4125436,
#  '\n （ 1 ）': 368762,
#  '（ 1 ）  ': 16390693,
#  '1 ）   的': 1663130,
#  '）   的 个数': 16501225,
#  '  的 个数 点': 833079,
#  '的 个数 点 全部': 13038444,
#  '个数 点 全部 的': 5455958,
#  '点 全部 的 。': 12626503,
#  '全部 的 。 \n': 6872327,
#  ...}

# %% [markdown]
# # Test

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from tabulate import tabulate

# %%
def predict_with_threshold(model, X, threshold=0.9):
    probabilities = model.predict_proba(X)
    
    positive_probabilities = probabilities[:, 1]
    
    predictions = (positive_probabilities > threshold).astype(int)
    
    return predictions

# %%
test_dataset = datadict["test"]

# %%
test_dataset = test_dataset.map(dataset_map_pre_process)
# Out:
# Loading cached processed dataset at /home/ran/.cache/huggingface/datasets/ranWang___parquet/ranWang--test_paper_textClassifier-e29578b85194b497/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-6dfa6fe4807d3d9d.arrow

# %%
import time

start_time = time.time()

predictions = predict_with_threshold(model, test_dataset["text"])

print(f"time { time.time() - start_time}")
# Out:
# time 13.097956418991089

# %%
accuracy = accuracy_score(test_dataset["label"], predictions)
recall = recall_score(test_dataset["label"], predictions)
precision = precision_score(test_dataset["label"], predictions)
f1 = f1_score(test_dataset["label"], predictions)

# %%
data = [["Accuracy", accuracy], ["Recall", recall], ["Precision", precision], ["F1 Score", f1]]

print(tabulate(data, headers=["Metric", "Score"]))
# Out:
# Metric        Score
# ---------  --------
# Accuracy   0.992248
# Recall     0.99505
# Precision  0.990148
# F1 Score   0.992593

# %% [markdown]
# # Check

# %%
# 1："试卷" 0:“其他”
for index, prediction in enumerate(predictions):
    if test_dataset['label'][index] != prediction:
        print(f"{index}  预期:{test_dataset['label'][index]} -- 结果:{prediction}")
# Out:
# 11  预期:1 -- 结果:0
# 342  预期:0 -- 结果:1
# 386  预期:0 -- 结果:1

# %%
for line in test_dataset["text"][11].splitlines():
    print(line)
# Out:
# Fr高考英语秋季班
#
# 43\. Accor o h ss, rslc s  vul's bly \_\_\_\_\_\_\_\_\_\_\_\_. 细节 --- 位置+对象
# A. o  crclly
# B. o c o's ow
# C. o lv
# D. o rcovr fro vrsy
# 44\. Wh os h url wor ""   rfr o? 细节 代词向前指代 --- 复数名词
# A. Th sycholoss
# B. Th  chlr
# C. Posv ls
# D. Irl locus of corol 单数
# 45\. Accor o , w c lr h \_\_\_\_\_\_\_\_\_\_\_\_. 细节---第四段重点内容---主题
# A. your  y . 主题
# B.  r or rcv h . vs对比
# C. xrc vrsy rcs h you wll . 肯定
# D.  os' ur you wll .
# 46\. Wh s h uhor's uros of wr hs ss?
# 主旨---开头结尾
# A. To ch ol how o b .
# B. To  ol o lv hrouh vrsy.
# C. To c ol's rco  fro ch ohr. 对比 彼此不同
# D. To  ffr rsrch fs bou . 对比---说明主题的写作方法
#
# 67\. Th sycholoss fro h Uvrsy of Mch f h \_\_\_\_\_\_\_\_\_\_\_\_. 研究结论
# A.   o chv succss
# B.  r lkly o
# C.   o sh
# D.  r coforbl wh work
# 国家对比---文化差异
# 68\. Th fl xr  \_\_\_\_\_\_\_\_\_\_\_\_. 细节
# A. cor ffr  owr
# B. f ffr vws bou rsol succss
# C. ju  of ffr rous
# D. cofr whch  s br
# 69\. A  wll b or ssf f h  fro \_\_\_\_\_\_\_\_\_\_\_\_. 细节
# A. hs hbors
# B. hs clsss
# C. hs chrs
# D. hs rs
# 70\. Accor o K Wu,  \_\_\_\_\_\_\_\_\_\_\_\_. 细节
# A. ly  ky rol  ol's choc k
# B. shows who w row u o b  h fuur
# C. s h os or fcor bh succss
# D. rs su's cc rforc
#
# A. Is  y . 温度不同
# B.   , hr,  cool. 连续动作
# C. Kls   usry   crf-k. 用途
# D. Kls   us . 过去现在
# E.  s  h chbr us o rsfor rls. 定义
# F. Mos ufcurrs us  s   hr r.
# G. , wh h rorly, bcos hr ouh o for .
#
# A. Polc rck srs  rr-qu crs.
# B. Ths surs r ow hhly ccur.
# C. Th vc c b us   w r of fls.
# D. I s hrfor sclly vlubl o shrs  rvlrs.
# E. Dur Worl Wr II y cours us rr ffcvly.
# F. Toy rr s us by corcl rlrs  whr forcsrs.
# G. Srh ol fs s o of rr's os or fucos.
